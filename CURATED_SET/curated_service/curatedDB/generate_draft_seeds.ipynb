# %%
import glob
import io
import json
import os
import shutil
import subprocess
import sys

import numpy as np
import pandas as pd
from Bio import AlignIO, Entrez, SearchIO, SeqIO
from Bio.Align import MultipleSeqAlignment
from Bio.Align.AlignInfo import SummaryInfo
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from ete3 import Tree
from pynucl.hist_features import hist_features
# Out:
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/Bio/Align/substitution_matrices/__init__.py:21: BiopythonExperimentalWarning: Bio.Align.substitution_matrices is an experimental module which may still undergo significant changes. In particular, the location of this module may change, and the Array class defined in this module may be moved to other existing or new modules in Biopython.
#   BiopythonExperimentalWarning)

# %%
def dict2tree(tree, d):
    """
    converts tree from classification.json to a ete3 object
    d is
    with open('classification.json') as json_file:
        data = json.load(json_file)
    d=data['tree']
    """
    for k, v in d.items():
        CH = tree.add_child(name=k)
        if isinstance(v, dict):
            dict2tree(CH, v)

# %%
def muscle_aln(sequences, options=[], debug=False, sort=True):
    muscle = os.path.join(os.path.dirname(sys.executable), "muscle")
    process = subprocess.Popen(
        [muscle] + options,
        stdin=subprocess.PIPE,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
    )
    aln, error = process.communicate(sequences.encode("utf-8"))
    if debug:
        print(sequences)
        print()
        print("Stderr:")
        print(error.decode("utf-8"))
        print("Stdout:")
        print(aln.decode("utf-8"))
    seqFile = io.StringIO()
    seqFile.write(aln.decode("utf-8"))
    seqFile.seek(0)
    sequences_ids = [s.split(" ", 1)[0] for s in sequences.split(">")]
    sequences = list(
        SeqIO.parse(seqFile, "fasta")
    )  # Not in same order, but does it matter?
    if sort:
        sequences.sort(key=lambda x: sequences_ids.index(x.id))  # Yes, it matters
    msa = MultipleSeqAlignment(sequences)
    return msa

# %%
def muscle_p2p_aln(msa1, msa2, options=[], debug=False):
    """
    align two alignments
    :return: MultipleSeqAlignment object
    """
    os.makedirs("tmp/")  # create tmp dir to save msa profiles
    try:
        with open("tmp/one.afa", "w") as f:
            f.write(format(msa1, "fasta"))
        with open("tmp/two.afa", "w") as f:
            f.write(format(msa2, "fasta"))

        muscle = os.path.join(os.path.dirname(sys.executable), "muscle")
        process = subprocess.Popen(
            [muscle]
            + options
            + ["-profile", "-in1", "tmp/one.afa", "-in2", "tmp/two.afa"],
            stdin=subprocess.PIPE,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
        )

        aln, error = process.communicate()
        if debug:
            print("Stderr:")
            print(error.decode("utf-8"))
            print("Stdout:")
            print(aln.decode("utf-8"))

        seqFile = io.StringIO()
        seqFile.write(aln.decode("utf-8"))
        seqFile.seek(0)
        sequences = list(
            SeqIO.parse(seqFile, "fasta")
        )  # Not in same order, but does it matter?
        msa = MultipleSeqAlignment(sequences)
    except:
        shutil.rmtree("tmp/")
        raise
    shutil.rmtree("tmp/")  # rm -rf tmp dir
    return msa

# %%
def get_fasta_seq(data):
    return "\n".join(
        [
            SeqRecord(
                Seq(row["sequence"]),
                # id=f"{row['organism'].split()[0]}|{row['accession']}|{row['variant']}",
                # в id не должно быть пробелов!
                id=f"{row['variant'].replace('(', '').replace(')', '')}_{row['organism'].replace(' ', '_').replace(':', '_')}_{row['accession']}",
                name=row["accession"],
                description=f"organism={row['organism']} phylum={row['phylum']} class={row['class']}".replace(
                    ":", " "
                ),
            ).format("fasta")
            for i, row in data.iterrows()
        ]
    )

# %%
def delete_gff_files(directory):
    # Находим все файлы с расширением .gff в указанной папке
    gff_files = glob.glob(os.path.join(directory, "*.gff"))

    # Удаляем каждый файл
    for file_path in gff_files:
        try:
            os.remove(file_path)
        except Exception as e:
            print(f"Не удалось удалить файл {file_path}: {e}")

# %%
def delete_tree_files(directory):
    # Находим все файлы с расширением .gff в указанной папке
    gff_files = glob.glob(os.path.join(directory, "*.tree"))

    # Удаляем каждый файл
    for file_path in gff_files:
        try:
            os.remove(file_path)
        except Exception as e:
            print(f"Не удалось удалить файл {file_path}: {e}")

# %%
class _IdHandler:
    """Generate IDs for GFF3 Parent/Child relationships where they don't exist."""

    def __init__(self):
        self._prefix = "biopygen"
        self._counter = 1
        self._seen_ids = []

    def _generate_id(self, quals):
        """Generate a unique ID not present in our existing IDs."""
        gen_id = self._get_standard_id(quals)
        if gen_id is None:
            while 1:
                gen_id = "%s%s" % (self._prefix, self._counter)
                if gen_id not in self._seen_ids:
                    break
                self._counter += 1
        return gen_id

    def _get_standard_id(self, quals):
        """Retrieve standardized IDs from other sources like NCBI GenBank.

        This tries to find IDs from known key/values when stored differently
        than GFF3 specifications.
        """
        possible_keys = ["transcript_id", "protein_id"]
        for test_key in possible_keys:
            if test_key in quals:
                cur_id = quals[test_key]
                if isinstance(cur_id, tuple) or isinstance(cur_id, list):
                    return cur_id[0]
                else:
                    return cur_id
        return None

    def update_quals(self, quals, has_children):
        """Update a set of qualifiers, adding an ID if necessary."""
        cur_id = quals.get("ID", None)
        # if we have an ID, record it
        if cur_id:
            if not isinstance(cur_id, list) and not isinstance(cur_id, tuple):
                cur_id = [cur_id]
            for add_id in cur_id:
                self._seen_ids.append(add_id)
        # if we need one and don't have it, create a new one
        elif has_children:
            new_id = self._generate_id(quals)
            self._seen_ids.append(new_id)
            quals["ID"] = [new_id]
        return quals

# %%
class GFF3Writer:
    """Write GFF3 files starting with standard Biopython objects."""

    def __init__(self):
        pass

    def write(self, recs, out_handle, include_fasta=False, filterids=[]):
        """Write the provided records to the given handle in GFF3 format."""
        self.filterids = filterids
        id_handler = _IdHandler()
        self._write_header(out_handle)
        fasta_recs = []
        try:
            recs = iter(recs)
        except TypeError:
            recs = [recs]
        for rec in recs:
            self._write_rec(rec, out_handle)
            self._write_annotations(rec.annotations, rec.id, len(rec.seq), out_handle)
            for sf in rec.features:
                if sf.id in self.filterids:
                    continue
                sf = self._clean_feature(sf)
                id_handler = self._write_feature(sf, rec.id, out_handle, id_handler)
            if include_fasta and len(rec.seq) > 0:
                fasta_recs.append(rec)
        if len(fasta_recs) > 0:
            self._write_fasta(fasta_recs, out_handle)

    def _clean_feature(self, feature):
        quals = {}
        for key, val in feature.qualifiers.items():
            if not isinstance(val, (list, tuple)):
                val = [val]
            val = [str(x) for x in val]
            quals[key] = val
        feature.qualifiers = quals
        # Support for Biopython 1.68 and above, which removed sub_features
        if not hasattr(feature, "sub_features"):
            feature.sub_features = []
        clean_sub = [self._clean_feature(f) for f in feature.sub_features]
        feature.sub_features = clean_sub
        return feature

    def _write_rec(self, rec, out_handle):
        # if we have a SeqRecord, write out optional directive
        if len(rec.seq) > 0:
            out_handle.write("##sequence-region %s 1 %s\n" % (rec.id, len(rec.seq)))

    def _get_phase(self, feature):
        if "phase" in feature.qualifiers:
            phase = feature.qualifiers["phase"][0]
        elif feature.type == "CDS":
            phase = int(feature.qualifiers.get("codon_start", [1])[0]) - 1
        else:
            phase = "."
        return str(phase)

    def _write_feature(self, feature, rec_id, out_handle, id_handler, parent_id=None):
        """Write a feature with location information."""
        if feature.strand == 1:
            strand = "+"
        elif feature.strand == -1:
            strand = "-"
        else:
            strand = "."
        # remove any standard features from the qualifiers
        quals = feature.qualifiers.copy()
        for std_qual in ["source", "score", "phase"]:
            if std_qual in quals and len(quals[std_qual]) == 1:
                del quals[std_qual]
        # add a link to a parent identifier if it exists
        if parent_id:
            if not "Parent" in quals:
                quals["Parent"] = []
            quals["Parent"].append(parent_id)
        quals = id_handler.update_quals(quals, len(feature.sub_features) > 0)
        if feature.type:
            ftype = feature.type
        else:
            ftype = "sequence_feature"
        parts = [
            str(rec_id),
            feature.qualifiers.get("source", ["feature"])[0],
            ftype,
            str(feature.location.nofuzzy_start + 1),  # 1-based indexing
            str(feature.location.nofuzzy_end),
            feature.qualifiers.get("score", ["."])[0],
            strand,
            self._get_phase(feature),
            self._format_keyvals(quals),
        ]
        out_handle.write("\t".join(parts) + "\n")
        for sub_feature in feature.sub_features:
            id_handler = self._write_feature(
                sub_feature, rec_id, out_handle, id_handler, quals["ID"][0]
            )
        return id_handler

    def _format_keyvals(self, keyvals):
        format_kvs = []
        for key in sorted(keyvals.keys()):
            values = keyvals[key]
            key = key.strip()
            format_vals = []
            if not isinstance(values, list) or isinstance(values, tuple):
                values = [values]
            for val in values:
                # val = urllib.parse.quote(str(val).strip(), safe=":/ ")
                if (key and val) and val not in format_vals:
                    format_vals.append(val)
            format_kvs.append("%s=%s" % (key, ",".join(format_vals)))
        return ";".join(format_kvs)

    def _write_annotations(self, anns, rec_id, size, out_handle):
        """Add annotations which refer to an entire sequence."""
        format_anns = self._format_keyvals(anns)
        if format_anns:
            parts = [
                rec_id,
                "annotation",
                "remark",
                "1",
                str(size if size > 1 else 1),
                ".",
                ".",
                ".",
                format_anns,
            ]
            out_handle.write("\t".join(parts) + "\n")

    def _write_header(self, out_handle):
        """Write out standard header directives."""
        out_handle.write("##gff-version 3\n")

    def _write_fasta(self, recs, out_handle):
        """Write sequence records using the ##FASTA directive."""
        out_handle.write("##FASTA\n")
        SeqIO.write(recs, out_handle, "fasta")

# %%
def GFFwrite(recs, out_handle, include_fasta=False, filterids=[]):
    """High level interface to write GFF3 files from SeqRecords and SeqFeatures.

    If include_fasta is True, the GFF3 file will include sequence information
    using the ##FASTA directive.
    """
    writer = GFF3Writer()
    return writer.write(recs, out_handle, include_fasta, filterids)

# %%
def generate_draft_seeds(hist_tree, sequence_data, save_directory):
    # generate draft seeds - needs debugging
    draft_seeds_msa = {}

    # create directory if not exist or rewrite the directory
    try:
        os.makedirs(save_directory)
    except FileExistsError:
        # directory already exists
        shutil.rmtree(save_directory)
        os.makedirs(save_directory)

    # hist_tree traversal
    for node in hist_tree.traverse("postorder"):
        print("Processing ", node.name)
        if node.is_root():
            continue
        if node.is_leaf():  # we get sequences for that variant and align them.
            draft_seeds_msa[node.name] = muscle_aln(
                get_fasta_seq(
                    sequence_data.query(
                        f'type=="{node.name}" | variant=="{node.name}"',
                        engine="python",
                    )
                )
            )
            print(node.name, "Alignment length:", len(draft_seeds_msa[node.name]))
            with open(
                f"{save_directory}/{node.name.replace('(', '').replace(')', '')}.fasta",
                "w",
            ) as f:
                f.write(format(draft_seeds_msa[node.name], "fasta"))
        elif not node.is_root():  # we will do profile to profile alignment
            # we should first check if there are seqs with this subvariant as the most specific one
            print(f"\t Node is internal, progressive alignment:")
            msa = muscle_aln(
                get_fasta_seq(sequence_data.query(f'variant=="{node.name}"'))
            )
            draft_seeds_msa[node.name + "_only"] = msa
            print(f"\t\t For {node.name} aligned {len(msa)} sequences")
            # progressively align
            for ch in node.get_children():
                if len(msa) == 0:
                    msa = draft_seeds_msa[ch.name]
                    print(
                        f"\t\t Adding child {node.name} aligned {len(draft_seeds_msa[ch.name])} sequences"
                    )
                    continue
                elif len(draft_seeds_msa[ch.name]) != 0:
                    msa = muscle_p2p_aln(msa, draft_seeds_msa[ch.name])
                    print(
                        f"\t\t Adding child {node.name} aligned {len(draft_seeds_msa[ch.name])} sequences"
                    )
                else:
                    continue
            draft_seeds_msa[node.name] = msa
            print(node.name, "Alignment length:", len(draft_seeds_msa[node.name]))
            with open(
                f"{save_directory}/{node.name.replace('(', '').replace(')', '')}.fasta",
                "w",
            ) as f:
                f.write(format(draft_seeds_msa[node.name], "fasta"))
            with open(
                f"{save_directory}/{node.name.replace('(', '').replace(')', '')}_only.fasta",
                "w",
            ) as f:
                f.write(format(draft_seeds_msa[node.name + "_only"], "fasta"))
        #         print(f"\t\t Final for {node.name} aligned {len(draft_seeds_msa[node.name])} sequences")

# %%
# Load curated seeds by traversing the tree
def generate_gff(curated_seeds_msa_form_files, save_directory):
    # firstly, delete all gff files
    # delete_gff_files(save_directory)
    for k, v in curated_seeds_msa_form_files.items():
        if not isinstance(v, list):
            cons = SummaryInfo(v).dumb_consensus(threshold=0.1, ambiguous="X")
            f = hist_features(cons)
            r = SeqRecord(seq=cons, id="Consensus", name="Consensus", features=f)
            with open(
                f"{save_directory}/{k.replace('(', '').replace(')', '')}.gff3", "w"
            ) as j:
                GFFwrite([r], j, filterids=["inner_core"])

# %%
def generate_core_seeds(curated_seeds_msa_form_files, save_directory):
    # create directory if not exist or rewrite the directory
    try:
        os.makedirs(save_directory)
    except FileExistsError:
        # directory already exists
        shutil.rmtree(save_directory)
        os.makedirs(save_directory)

    for k, msa in curated_seeds_msa_form_files.items():
        if not isinstance(msa, list):
            core = hist_features(
                SummaryInfo(msa).dumb_consensus(threshold=0.1, ambiguous="X")
            )[1]
            msa_core = msa[:, core.location.start : core.location.end]
            with open(
                f"{save_directory}/{k.replace('(', '').replace(')', '')}.fasta", "w"
            ) as f:
                f.write(msa_core.format("fasta"))

# %% [markdown]
# # Generate draft seeds

# %%
DIR = "/home/l_singh/_scratch/hdb/project_dir/histonedb/CURATED_SET"

# %%
with open(f"{DIR}/classification.json") as json_file:
    data = json.load(json_file)
hist_tree = Tree()
dict2tree(hist_tree, data["tree"])
# print(hist_tree.get_ascii(show_internal=True))

# %%
sequence_df = pd.read_csv(f"{DIR}/histones.csv").fillna("")
sequence_df.index = list(sequence_df["accession"])

# %%
# %%time
generate_draft_seeds(
    hist_tree,
    sequence_df,
    f"{DIR}/draft_seeds",
)
# Out:
# Processing  cH2A.10_(Homo_sapiens)
# cH2A.10_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.11_(Homo_sapiens)
# cH2A.11_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.1_(Homo_sapiens)
# cH2A.1_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.2_(Homo_sapiens)
# cH2A.2_(Homo_sapiens) Alignment length: 2
# Processing  cH2A.3_(Homo_sapiens)
# cH2A.3_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.4_(Homo_sapiens)
# cH2A.4_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.5_(Homo_sapiens)
# cH2A.5_(Homo_sapiens) Alignment length: 5
# Processing  cH2A.6_(Homo_sapiens)
# cH2A.6_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.7_(Homo_sapiens)
# cH2A.7_(Homo_sapiens) Alignment length: 1
# Processing  cH2A.8_(Homo_sapiens)
# cH2A.8_(Homo_sapiens) Alignment length: 2
# Processing  cH2A.9_(Homo_sapiens)
# cH2A.9_(Homo_sapiens) Alignment length: 1
# Processing  cH2A_(Homo_sapiens)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Homo_sapiens) aligned 0 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 2 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 5 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 2 sequences
# 		 Adding child cH2A_(Homo_sapiens) aligned 1 sequences
# cH2A_(Homo_sapiens) Alignment length: 17
# Processing  cH2A.1_(Mus_musculus)
# cH2A.1_(Mus_musculus) Alignment length: 1
# Processing  cH2A_(Mus_musculus)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Mus_musculus) aligned 0 sequences
# 		 Adding child cH2A_(Mus_musculus) aligned 1 sequences
# cH2A_(Mus_musculus) Alignment length: 1
# Processing  cH2A_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Mammalia) aligned 16 sequences
# 		 Adding child cH2A_(Mammalia) aligned 17 sequences
# 		 Adding child cH2A_(Mammalia) aligned 1 sequences
# cH2A_(Mammalia) Alignment length: 34
# Processing  cH2A_(Vertebrata)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Vertebrata) aligned 3 sequences
# 		 Adding child cH2A_(Vertebrata) aligned 34 sequences
# cH2A_(Vertebrata) Alignment length: 37
# Processing  cH2A_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Animals) aligned 5 sequences
# 		 Adding child cH2A_(Animals) aligned 37 sequences
# cH2A_(Animals) Alignment length: 42
# Processing  cH2A_(Fungi)
# cH2A_(Fungi) Alignment length: 2
# Processing  cH2A_(Chlorophyta)
# cH2A_(Chlorophyta) Alignment length: 1
# Processing  cH2A_(Embryophyta)
# cH2A_(Embryophyta) Alignment length: 8
# Processing  cH2A_(Plants)
# 	 Node is internal, progressive alignment:
# 		 For cH2A_(Plants) aligned 0 sequences
# 		 Adding child cH2A_(Plants) aligned 1 sequences
# 		 Adding child cH2A_(Plants) aligned 8 sequences
# cH2A_(Plants) Alignment length: 9
# Processing  cH2A_(Protists)
# cH2A_(Protists) Alignment length: 4
# Processing  cH2A
# 	 Node is internal, progressive alignment:
# 		 For cH2A aligned 0 sequences
# 		 Adding child cH2A aligned 42 sequences
# 		 Adding child cH2A aligned 2 sequences
# 		 Adding child cH2A aligned 9 sequences
# 		 Adding child cH2A aligned 4 sequences
# cH2A Alignment length: 57
# Processing  gH2A_(Lilium)
# gH2A_(Lilium) Alignment length: 1
# Processing  H2A.J_(Homo_sapiens)
# H2A.J_(Homo_sapiens) Alignment length: 1
# Processing  H2A.J
# 	 Node is internal, progressive alignment:
# 		 For H2A.J aligned 0 sequences
# 		 Adding child H2A.J aligned 1 sequences
# H2A.J Alignment length: 1
# Processing  H2A.M_(Viridiplantae)
# H2A.M_(Viridiplantae) Alignment length: 7
# Processing  H2A.R
# H2A.R Alignment length: 5
# Processing  H2A.W_(Magnoliopsida)
# H2A.W_(Magnoliopsida) Alignment length: 9
# Processing  H2A.X_(Homo_sapiens)
# H2A.X_(Homo_sapiens) Alignment length: 1
# Processing  H2A.X_(Mus_musculus)
# H2A.X_(Mus_musculus) Alignment length: 1
# Processing  H2A.X_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For H2A.X_(Mammalia) aligned 3 sequences
# 		 Adding child H2A.X_(Mammalia) aligned 1 sequences
# 		 Adding child H2A.X_(Mammalia) aligned 1 sequences
# H2A.X_(Mammalia) Alignment length: 5
# Processing  H2A.X_(Vertebrata)
# 	 Node is internal, progressive alignment:
# 		 For H2A.X_(Vertebrata) aligned 1 sequences
# 		 Adding child H2A.X_(Vertebrata) aligned 5 sequences
# H2A.X_(Vertebrata) Alignment length: 6
# Processing  H2A.X_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For H2A.X_(Animals) aligned 2 sequences
# 		 Adding child H2A.X_(Animals) aligned 6 sequences
# H2A.X_(Animals) Alignment length: 8
# Processing  H2A.X_(Fungi)
# H2A.X_(Fungi) Alignment length: 4
# Processing  H2A.X_(Plants)
# H2A.X_(Plants) Alignment length: 5
# Processing  H2A.X_(Protists)
# H2A.X_(Protists) Alignment length: 6
# Processing  H2A.X
# 	 Node is internal, progressive alignment:
# 		 For H2A.X aligned 0 sequences
# 		 Adding child H2A.X aligned 8 sequences
# 		 Adding child H2A.X aligned 4 sequences
# 		 Adding child H2A.X aligned 5 sequences
# 		 Adding child H2A.X aligned 6 sequences
# H2A.X Alignment length: 23
# Processing  H2A.Z.1_(Homo_sapiens)
# H2A.Z.1_(Homo_sapiens) Alignment length: 1
# Processing  H2A.Z.1_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.1_(Primates) aligned 0 sequences
# 		 Adding child H2A.Z.1_(Primates) aligned 1 sequences
# H2A.Z.1_(Primates) Alignment length: 1
# Processing  H2A.Z.1_(Chordata)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.1_(Chordata) aligned 2 sequences
# 		 Adding child H2A.Z.1_(Chordata) aligned 1 sequences
# H2A.Z.1_(Chordata) Alignment length: 3
# Processing  H2A.Z.2.s1_(Homo_sapiens)
# H2A.Z.2.s1_(Homo_sapiens) Alignment length: 3
# Processing  H2A.Z.2.s1_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.2.s1_(Primates) aligned 0 sequences
# 		 Adding child H2A.Z.2.s1_(Primates) aligned 3 sequences
# H2A.Z.2.s1_(Primates) Alignment length: 3
# Processing  H2A.Z.2.s2_(Homo_sapiens)
# H2A.Z.2.s2_(Homo_sapiens) Alignment length: 2
# Processing  H2A.Z.2.s2_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.2.s2_(Primates) aligned 0 sequences
# 		 Adding child H2A.Z.2.s2_(Primates) aligned 2 sequences
# H2A.Z.2.s2_(Primates) Alignment length: 2
# Processing  H2A.Z.2_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.2_(Primates) aligned 0 sequences
# 		 Adding child H2A.Z.2_(Primates) aligned 3 sequences
# 		 Adding child H2A.Z.2_(Primates) aligned 2 sequences
# H2A.Z.2_(Primates) Alignment length: 5
# Processing  H2A.Z.2_(Chordata)
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z.2_(Chordata) aligned 2 sequences
# 		 Adding child H2A.Z.2_(Chordata) aligned 5 sequences
# H2A.Z.2_(Chordata) Alignment length: 7
# Processing  H2A.Z
# 	 Node is internal, progressive alignment:
# 		 For H2A.Z aligned 20 sequences
# 		 Adding child H2A.Z aligned 3 sequences
# 		 Adding child H2A.Z aligned 7 sequences
# H2A.Z Alignment length: 30
# Processing  macroH2A.1.s1_(Homo_sapiens)
# macroH2A.1.s1_(Homo_sapiens) Alignment length: 1
# Processing  macroH2A.1.s1_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For macroH2A.1.s1_(Mammalia) aligned 0 sequences
# 		 Adding child macroH2A.1.s1_(Mammalia) aligned 1 sequences
# macroH2A.1.s1_(Mammalia) Alignment length: 1
# Processing  macroH2A.1.s2_(Homo_sapiens)
# macroH2A.1.s2_(Homo_sapiens) Alignment length: 2
# Processing  macroH2A.1.s2_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For macroH2A.1.s2_(Mammalia) aligned 0 sequences
# 		 Adding child macroH2A.1.s2_(Mammalia) aligned 2 sequences
# macroH2A.1.s2_(Mammalia) Alignment length: 2
# Processing  macroH2A.1_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For macroH2A.1_(Mammalia) aligned 0 sequences
# 		 Adding child macroH2A.1_(Mammalia) aligned 1 sequences
# 		 Adding child macroH2A.1_(Mammalia) aligned 2 sequences
# macroH2A.1_(Mammalia) Alignment length: 3
# Processing  macroH2A.2_(Homo_sapiens)
# macroH2A.2_(Homo_sapiens) Alignment length: 1
# Processing  macroH2A.2_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For macroH2A.2_(Mammalia) aligned 0 sequences
# 		 Adding child macroH2A.2_(Mammalia) aligned 1 sequences
# macroH2A.2_(Mammalia) Alignment length: 1
# Processing  macroH2A
# 	 Node is internal, progressive alignment:
# 		 For macroH2A aligned 7 sequences
# 		 Adding child macroH2A aligned 3 sequences
# 		 Adding child macroH2A aligned 1 sequences
# macroH2A Alignment length: 11
# Processing  H2A.B.1_(Homo_sapiens)
# H2A.B.1_(Homo_sapiens) Alignment length: 1
# Processing  H2A.B.2_(Homo_sapiens)
# H2A.B.2_(Homo_sapiens) Alignment length: 2
# Processing  H2A.B_(Homo_sapiens)
# 	 Node is internal, progressive alignment:
# 		 For H2A.B_(Homo_sapiens) aligned 0 sequences
# 		 Adding child H2A.B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child H2A.B_(Homo_sapiens) aligned 2 sequences
# H2A.B_(Homo_sapiens) Alignment length: 3
# Processing  H2A.B.1_(Mus_musculus)
# H2A.B.1_(Mus_musculus) Alignment length: 1
# Processing  H2A.B.2_(Mus_musculus)
# H2A.B.2_(Mus_musculus) Alignment length: 1
# Processing  H2A.B.3_(Mus_musculus)
# H2A.B.3_(Mus_musculus) Alignment length: 1
# Processing  H2A.B_(Mus_musculus)
# 	 Node is internal, progressive alignment:
# 		 For H2A.B_(Mus_musculus) aligned 0 sequences
# 		 Adding child H2A.B_(Mus_musculus) aligned 1 sequences
# 		 Adding child H2A.B_(Mus_musculus) aligned 1 sequences
# 		 Adding child H2A.B_(Mus_musculus) aligned 1 sequences
# H2A.B_(Mus_musculus) Alignment length: 3
# Processing  H2A.B_(Eutheria)
# 	 Node is internal, progressive alignment:
# 		 For H2A.B_(Eutheria) aligned 11 sequences
# 		 Adding child H2A.B_(Eutheria) aligned 3 sequences
# 		 Adding child H2A.B_(Eutheria) aligned 3 sequences
# H2A.B_(Eutheria) Alignment length: 17
# Processing  H2A.L.1_(Homo_sapiens)
# H2A.L.1_(Homo_sapiens) Alignment length: 1
# Processing  H2A.L.3_(Homo_sapiens)
# H2A.L.3_(Homo_sapiens) Alignment length: 1
# Processing  H2A.L_(Homo_sapiens)
# 	 Node is internal, progressive alignment:
# 		 For H2A.L_(Homo_sapiens) aligned 0 sequences
# 		 Adding child H2A.L_(Homo_sapiens) aligned 1 sequences
# 		 Adding child H2A.L_(Homo_sapiens) aligned 1 sequences
# H2A.L_(Homo_sapiens) Alignment length: 2
# Processing  H2A.L.1_(Mus_musculus)
# H2A.L.1_(Mus_musculus) Alignment length: 1
# Processing  H2A.L.2_(Mus_musculus)
# H2A.L.2_(Mus_musculus) Alignment length: 1
# Processing  H2A.L.3_(Mus_musculus)
# H2A.L.3_(Mus_musculus) Alignment length: 1
# Processing  H2A.L_(Mus_musculus)
# 	 Node is internal, progressive alignment:
# 		 For H2A.L_(Mus_musculus) aligned 0 sequences
# 		 Adding child H2A.L_(Mus_musculus) aligned 1 sequences
# 		 Adding child H2A.L_(Mus_musculus) aligned 1 sequences
# 		 Adding child H2A.L_(Mus_musculus) aligned 1 sequences
# H2A.L_(Mus_musculus) Alignment length: 3
# Processing  H2A.L_(Eutheria)
# 	 Node is internal, progressive alignment:
# 		 For H2A.L_(Eutheria) aligned 15 sequences
# 		 Adding child H2A.L_(Eutheria) aligned 2 sequences
# 		 Adding child H2A.L_(Eutheria) aligned 3 sequences
# H2A.L_(Eutheria) Alignment length: 20
# Processing  H2A.P_(Homo_sapiens)
# H2A.P_(Homo_sapiens) Alignment length: 1
# Processing  H2A.P_(Mus_musculus)
# H2A.P_(Mus_musculus) Alignment length: 1
# Processing  H2A.P_(Eutheria)
# 	 Node is internal, progressive alignment:
# 		 For H2A.P_(Eutheria) aligned 8 sequences
# 		 Adding child H2A.P_(Eutheria) aligned 1 sequences
# 		 Adding child H2A.P_(Eutheria) aligned 1 sequences
# H2A.P_(Eutheria) Alignment length: 10
# Processing  H2A.Q_(Eutheria)
# H2A.Q_(Eutheria) Alignment length: 28
# Processing  short_H2A_(Eutheria)
# 	 Node is internal, progressive alignment:
# 		 For short_H2A_(Eutheria) aligned 0 sequences
# 		 Adding child short_H2A_(Eutheria) aligned 17 sequences
# 		 Adding child short_H2A_(Eutheria) aligned 20 sequences
# 		 Adding child short_H2A_(Eutheria) aligned 10 sequences
# 		 Adding child short_H2A_(Eutheria) aligned 28 sequences
# short_H2A_(Eutheria) Alignment length: 75
# Processing  H2A
# 	 Node is internal, progressive alignment:
# 		 For H2A aligned 0 sequences
# 		 Adding child H2A aligned 57 sequences
# 		 Adding child H2A aligned 1 sequences
# 		 Adding child H2A aligned 1 sequences
# 		 Adding child H2A aligned 7 sequences
# 		 Adding child H2A aligned 5 sequences
# 		 Adding child H2A aligned 9 sequences
# 		 Adding child H2A aligned 23 sequences
# 		 Adding child H2A aligned 30 sequences
# 		 Adding child H2A aligned 11 sequences
# 		 Adding child H2A aligned 75 sequences
# H2A Alignment length: 219
# Processing  cH2B.10_(Homo_sapiens)
# cH2B.10_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.11_(Homo_sapiens)
# cH2B.11_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.12_(Homo_sapiens)
# cH2B.12_(Homo_sapiens) Alignment length: 2
# Processing  cH2B.13_(Homo_sapiens)
# cH2B.13_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.14_(Homo_sapiens)
# cH2B.14_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.15_(Homo_sapiens)
# cH2B.15_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.1_(Homo_sapiens)
# cH2B.1_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.2_(Homo_sapiens)
# cH2B.2_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.3_(Homo_sapiens)
# cH2B.3_(Homo_sapiens) Alignment length: 5
# Processing  cH2B.4_(Homo_sapiens)
# cH2B.4_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.5_(Homo_sapiens)
# cH2B.5_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.6_(Homo_sapiens)
# cH2B.6_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.7_(Homo_sapiens)
# cH2B.7_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.8_(Homo_sapiens)
# cH2B.8_(Homo_sapiens) Alignment length: 1
# Processing  cH2B.9_(Homo_sapiens)
# cH2B.9_(Homo_sapiens) Alignment length: 1
# Processing  cH2B_(Homo_sapiens)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Homo_sapiens) aligned 0 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 2 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 5 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# 		 Adding child cH2B_(Homo_sapiens) aligned 1 sequences
# cH2B_(Homo_sapiens) Alignment length: 20
# Processing  cH2B.1_(Mus_musculus)
# cH2B.1_(Mus_musculus) Alignment length: 2
# Processing  cH2B.E_(Mus_musculus)
# cH2B.E_(Mus_musculus) Alignment length: 1
# Processing  cH2B_(Mus_musculus)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Mus_musculus) aligned 1 sequences
# 		 Adding child cH2B_(Mus_musculus) aligned 2 sequences
# 		 Adding child cH2B_(Mus_musculus) aligned 1 sequences
# cH2B_(Mus_musculus) Alignment length: 4
# Processing  cH2B_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Mammalia) aligned 16 sequences
# 		 Adding child cH2B_(Mammalia) aligned 20 sequences
# 		 Adding child cH2B_(Mammalia) aligned 4 sequences
# cH2B_(Mammalia) Alignment length: 40
# Processing  cH2B_(Vertebrata)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Vertebrata) aligned 2 sequences
# 		 Adding child cH2B_(Vertebrata) aligned 40 sequences
# cH2B_(Vertebrata) Alignment length: 42
# Processing  cH2B_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Animals) aligned 4 sequences
# 		 Adding child cH2B_(Animals) aligned 42 sequences
# cH2B_(Animals) Alignment length: 46
# Processing  cH2B_(Fungi)
# cH2B_(Fungi) Alignment length: 2
# Processing  cH2B_(Chlorophyta)
# cH2B_(Chlorophyta) Alignment length: 35
# Processing  cH2B_(Embryophyta)
# cH2B_(Embryophyta) Alignment length: 4
# Processing  cH2B_(Plants)
# 	 Node is internal, progressive alignment:
# 		 For cH2B_(Plants) aligned 0 sequences
# 		 Adding child cH2B_(Plants) aligned 35 sequences
# 		 Adding child cH2B_(Plants) aligned 4 sequences
# cH2B_(Plants) Alignment length: 39
# Processing  cH2B_(Protists)
# cH2B_(Protists) Alignment length: 1
# Processing  cH2B
# 	 Node is internal, progressive alignment:
# 		 For cH2B aligned 0 sequences
# 		 Adding child cH2B aligned 46 sequences
# 		 Adding child cH2B aligned 2 sequences
# 		 Adding child cH2B aligned 39 sequences
# 		 Adding child cH2B aligned 1 sequences
# cH2B Alignment length: 88
# Processing  CS_H2B_(Echinoidea)
# CS_H2B_(Echinoidea) Alignment length: 1
# Processing  early_H2B_(Echinoidea)
# early_H2B_(Echinoidea) Alignment length: 1
# Processing  gH2B_(Lilium)
# gH2B_(Lilium) Alignment length: 3
# Processing  H2B.K_(Homo_sapiens)
# H2B.K_(Homo_sapiens) Alignment length: 1
# Processing  H2B.K
# 	 Node is internal, progressive alignment:
# 		 For H2B.K aligned 19 sequences
# 		 Adding child H2B.K aligned 1 sequences
# H2B.K Alignment length: 20
# Processing  H2B.L
# H2B.L Alignment length: 11
# Processing  H2B.N_(Homo_sapiens)
# H2B.N_(Homo_sapiens) Alignment length: 1
# Processing  H2B.N
# 	 Node is internal, progressive alignment:
# 		 For H2B.N aligned 13 sequences
# 		 Adding child H2B.N aligned 1 sequences
# H2B.N Alignment length: 14
# Processing  H2B.O_(Ornithorhynchus_anatinus)
# H2B.O_(Ornithorhynchus_anatinus) Alignment length: 3
# Processing  H2B.S_(Magnoliopsida)
# H2B.S_(Magnoliopsida) Alignment length: 45
# Processing  H2B.V_(Trypanosoma)
# H2B.V_(Trypanosoma) Alignment length: 1
# Processing  H2B.W.1_(Homo_sapiens)
# H2B.W.1_(Homo_sapiens) Alignment length: 1
# Processing  H2B.W.2_(Homo_sapiens)
# H2B.W.2_(Homo_sapiens) Alignment length: 1
# Processing  H2B.W_(Homo_sapiens)
# 	 Node is internal, progressive alignment:
# 		 For H2B.W_(Homo_sapiens) aligned 0 sequences
# 		 Adding child H2B.W_(Homo_sapiens) aligned 1 sequences
# 		 Adding child H2B.W_(Homo_sapiens) aligned 1 sequences
# H2B.W_(Homo_sapiens) Alignment length: 2
# Processing  H2B.W
# 	 Node is internal, progressive alignment:
# 		 For H2B.W aligned 5 sequences
# 		 Adding child H2B.W aligned 2 sequences
# H2B.W Alignment length: 7
# Processing  H2B.Z_(Apicomplexa)
# H2B.Z_(Apicomplexa) Alignment length: 9
# Processing  late_H2B_(Echinoidea)
# late_H2B_(Echinoidea) Alignment length: 2
# Processing  sperm_H2B_(Echinoidea)
# sperm_H2B_(Echinoidea) Alignment length: 7
# Processing  H2B
# 	 Node is internal, progressive alignment:
# 		 For H2B aligned 0 sequences
# 		 Adding child H2B aligned 88 sequences
# 		 Adding child H2B aligned 1 sequences
# 		 Adding child H2B aligned 1 sequences
# 		 Adding child H2B aligned 3 sequences
# 		 Adding child H2B aligned 20 sequences
# 		 Adding child H2B aligned 11 sequences
# 		 Adding child H2B aligned 14 sequences
# 		 Adding child H2B aligned 3 sequences
# 		 Adding child H2B aligned 45 sequences
# 		 Adding child H2B aligned 1 sequences
# 		 Adding child H2B aligned 7 sequences
# 		 Adding child H2B aligned 9 sequences
# 		 Adding child H2B aligned 2 sequences
# 		 Adding child H2B aligned 7 sequences
# H2B Alignment length: 212
# Processing  cH3.1_(Homo_sapiens)
# cH3.1_(Homo_sapiens) Alignment length: 10
# Processing  cH3.1_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH3.1_(Mammalia) aligned 3 sequences
# 		 Adding child cH3.1_(Mammalia) aligned 10 sequences
# cH3.1_(Mammalia) Alignment length: 13
# Processing  cH3.2_(Homo_sapiens)
# cH3.2_(Homo_sapiens) Alignment length: 3
# Processing  cH3.2_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH3.2_(Mammalia) aligned 0 sequences
# 		 Adding child cH3.2_(Mammalia) aligned 3 sequences
# cH3.2_(Mammalia) Alignment length: 3
# Processing  cH3_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH3_(Mammalia) aligned 0 sequences
# 		 Adding child cH3_(Mammalia) aligned 13 sequences
# 		 Adding child cH3_(Mammalia) aligned 3 sequences
# cH3_(Mammalia) Alignment length: 16
# Processing  cH3_(Vertebrata)
# 	 Node is internal, progressive alignment:
# 		 For cH3_(Vertebrata) aligned 1 sequences
# 		 Adding child cH3_(Vertebrata) aligned 16 sequences
# cH3_(Vertebrata) Alignment length: 17
# Processing  cH3_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For cH3_(Animals) aligned 4 sequences
# 		 Adding child cH3_(Animals) aligned 17 sequences
# cH3_(Animals) Alignment length: 21
# Processing  cH3_(Fungi)
# cH3_(Fungi) Alignment length: 2
# Processing  cH3_(Chlorophyta)
# cH3_(Chlorophyta) Alignment length: 0
# Processing  cH3_(Embryophyta)
# cH3_(Embryophyta) Alignment length: 4
# Processing  cH3_(Plants)
# 	 Node is internal, progressive alignment:
# 		 For cH3_(Plants) aligned 0 sequences
# 		 Adding child cH3_(Plants) aligned 0 sequences
# 		 Adding child cH3_(Plants) aligned 4 sequences
# cH3_(Plants) Alignment length: 4
# Processing  cH3_(Protists)
# cH3_(Protists) Alignment length: 8
# Processing  cH3
# 	 Node is internal, progressive alignment:
# 		 For cH3 aligned 3 sequences
# 		 Adding child cH3 aligned 21 sequences
# 		 Adding child cH3 aligned 2 sequences
# 		 Adding child cH3 aligned 4 sequences
# 		 Adding child cH3 aligned 8 sequences
# cH3 Alignment length: 38
# Processing  cenH3.1_(Culicidae)
# cenH3.1_(Culicidae) Alignment length: 19
# Processing  cenH3.2_(Culicidae)
# cenH3.2_(Culicidae) Alignment length: 21
# Processing  cenH3.3_(Aedes)
# cenH3.3_(Aedes) Alignment length: 2
# Processing  cenH3_(Culicidae)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Culicidae) aligned 0 sequences
# 		 Adding child cenH3_(Culicidae) aligned 19 sequences
# 		 Adding child cenH3_(Culicidae) aligned 21 sequences
# 		 Adding child cenH3_(Culicidae) aligned 2 sequences
# cenH3_(Culicidae) Alignment length: 42
# Processing  cenH3.1_(Drosophilidae)
# cenH3.1_(Drosophilidae) Alignment length: 96
# Processing  cenH3.2_(Drosophila_eugracilis)
# cenH3.2_(Drosophila_eugracilis) Alignment length: 8
# Processing  cenH3.3_(Montium)
# cenH3.3_(Montium) Alignment length: 50
# Processing  cenH3.4_(Montium)
# cenH3.4_(Montium) Alignment length: 50
# Processing  cenH3.5_(Drosophila)
# cenH3.5_(Drosophila) Alignment length: 47
# Processing  cenH3.6_(Repleta)
# cenH3.6_(Repleta) Alignment length: 2
# Processing  cenH3_(Drosophilidae)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Drosophilidae) aligned 0 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 96 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 8 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 50 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 50 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 47 sequences
# 		 Adding child cenH3_(Drosophilidae) aligned 2 sequences
# cenH3_(Drosophilidae) Alignment length: 253
# Processing  cenH3_(Insecta)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Insecta) aligned 0 sequences
# 		 Adding child cenH3_(Insecta) aligned 42 sequences
# 		 Adding child cenH3_(Insecta) aligned 253 sequences
# cenH3_(Insecta) Alignment length: 295
# Processing  cenH3_(Homo_sapiens)
# cenH3_(Homo_sapiens) Alignment length: 2
# Processing  cenH3_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Mammalia) aligned 1 sequences
# 		 Adding child cenH3_(Mammalia) aligned 2 sequences
# cenH3_(Mammalia) Alignment length: 3
# Processing  cenH3_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Animals) aligned 1 sequences
# 		 Adding child cenH3_(Animals) aligned 295 sequences
# 		 Adding child cenH3_(Animals) aligned 3 sequences
# cenH3_(Animals) Alignment length: 299
# Processing  cenH3_(Fungi)
# cenH3_(Fungi) Alignment length: 2
# Processing  cenH3.1_(Triticeae)
# cenH3.1_(Triticeae) Alignment length: 3
# Processing  cenH3.2_(Triticeae)
# cenH3.2_(Triticeae) Alignment length: 3
# Processing  cenH3_(Triticeae)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Triticeae) aligned 0 sequences
# 		 Adding child cenH3_(Triticeae) aligned 3 sequences
# 		 Adding child cenH3_(Triticeae) aligned 3 sequences
# cenH3_(Triticeae) Alignment length: 6
# Processing  cenH3.1_(Vigna_unguiculata)
# cenH3.1_(Vigna_unguiculata) Alignment length: 13
# Processing  cenH3.2_(Vigna_unguiculata)
# cenH3.2_(Vigna_unguiculata) Alignment length: 13
# Processing  cenH3_(Vigna_unguiculata)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Vigna_unguiculata) aligned 0 sequences
# 		 Adding child cenH3_(Vigna_unguiculata) aligned 13 sequences
# 		 Adding child cenH3_(Vigna_unguiculata) aligned 13 sequences
# cenH3_(Vigna_unguiculata) Alignment length: 26
# Processing  cenH3_(Plants)
# 	 Node is internal, progressive alignment:
# 		 For cenH3_(Plants) aligned 130 sequences
# 		 Adding child cenH3_(Plants) aligned 6 sequences
# 		 Adding child cenH3_(Plants) aligned 26 sequences
# cenH3_(Plants) Alignment length: 162
# Processing  cenH3_(Protists)
# cenH3_(Protists) Alignment length: 1
# Processing  cenH3
# 	 Node is internal, progressive alignment:
# 		 For cenH3 aligned 5 sequences
# 		 Adding child cenH3 aligned 299 sequences
# 		 Adding child cenH3 aligned 2 sequences
# 		 Adding child cenH3 aligned 162 sequences
# 		 Adding child cenH3 aligned 1 sequences
# cenH3 Alignment length: 469
# Processing  H3-like_(Plants)
# H3-like_(Plants) Alignment length: 12
# Processing  H3.10_(Arabidopsis)
# H3.10_(Arabidopsis) Alignment length: 1
# Processing  H3.14_(Arabidopsis)
# H3.14_(Arabidopsis) Alignment length: 1
# Processing  H3.3_(Homo_sapiens)
# H3.3_(Homo_sapiens) Alignment length: 2
# Processing  H3.3_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For H3.3_(Animals) aligned 0 sequences
# 		 Adding child H3.3_(Animals) aligned 2 sequences
# H3.3_(Animals) Alignment length: 2
# Processing  H3.3_(Ascomycota)
# H3.3_(Ascomycota) Alignment length: 0
# Processing  H3.3_(Fungi)
# 	 Node is internal, progressive alignment:
# 		 For H3.3_(Fungi) aligned 0 sequences
# 		 Adding child H3.3_(Fungi) aligned 0 sequences
# H3.3_(Fungi) Alignment length: 0
# Processing  H3.3_(Plants)
# H3.3_(Plants) Alignment length: 0
# Processing  H3.3_(Protists)
# H3.3_(Protists) Alignment length: 0
# Processing  H3.3
# 	 Node is internal, progressive alignment:
# 		 For H3.3 aligned 18 sequences
# 		 Adding child H3.3 aligned 2 sequences
# H3.3 Alignment length: 20
# Processing  H3.4_(Homo_sapiens)
# H3.4_(Homo_sapiens) Alignment length: 1
# Processing  H3.4_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For H3.4_(Mammalia) aligned 3 sequences
# 		 Adding child H3.4_(Mammalia) aligned 1 sequences
# H3.4_(Mammalia) Alignment length: 4
# Processing  H3.5_(Homo_sapiens)
# H3.5_(Homo_sapiens) Alignment length: 1
# Processing  H3.5_(Hominidae)
# 	 Node is internal, progressive alignment:
# 		 For H3.5_(Hominidae) aligned 2 sequences
# 		 Adding child H3.5_(Hominidae) aligned 1 sequences
# H3.5_(Hominidae) Alignment length: 3
# Processing  H3.7_(Homo_sapiens)
# H3.7_(Homo_sapiens) Alignment length: 1
# Processing  H3.B_(Giardia)
# H3.B_(Giardia) Alignment length: 1
# Processing  H3.P_(Euplotes_crassus)
# H3.P_(Euplotes_crassus) Alignment length: 1
# Processing  H3.V_(Trypanosomatidae)
# H3.V_(Trypanosomatidae) Alignment length: 5
# Processing  H3.Y.1_(Homo_sapiens)
# H3.Y.1_(Homo_sapiens) Alignment length: 1
# Processing  H3.Y.1_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H3.Y.1_(Primates) aligned 2 sequences
# 		 Adding child H3.Y.1_(Primates) aligned 1 sequences
# H3.Y.1_(Primates) Alignment length: 3
# Processing  H3.Y.2_(Homo_sapiens)
# H3.Y.2_(Homo_sapiens) Alignment length: 1
# Processing  H3.Y.2_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H3.Y.2_(Primates) aligned 1 sequences
# 		 Adding child H3.Y.2_(Primates) aligned 1 sequences
# H3.Y.2_(Primates) Alignment length: 2
# Processing  H3.Y_(Primates)
# 	 Node is internal, progressive alignment:
# 		 For H3.Y_(Primates) aligned 0 sequences
# 		 Adding child H3.Y_(Primates) aligned 3 sequences
# 		 Adding child H3.Y_(Primates) aligned 2 sequences
# H3.Y_(Primates) Alignment length: 5
# Processing  H3
# 	 Node is internal, progressive alignment:
# 		 For H3 aligned 0 sequences
# 		 Adding child H3 aligned 38 sequences
# 		 Adding child H3 aligned 469 sequences
# 		 Adding child H3 aligned 12 sequences
# 		 Adding child H3 aligned 1 sequences
# 		 Adding child H3 aligned 1 sequences
# 		 Adding child H3 aligned 20 sequences
# 		 Adding child H3 aligned 4 sequences
# 		 Adding child H3 aligned 3 sequences
# 		 Adding child H3 aligned 1 sequences
# 		 Adding child H3 aligned 1 sequences
# 		 Adding child H3 aligned 1 sequences
# 		 Adding child H3 aligned 5 sequences
# 		 Adding child H3 aligned 5 sequences
# H3 Alignment length: 561
# Processing  cH4_(Homo_sapiens)
# cH4_(Homo_sapiens) Alignment length: 14
# Processing  cH4_(Mammalia)
# 	 Node is internal, progressive alignment:
# 		 For cH4_(Mammalia) aligned 2 sequences
# 		 Adding child cH4_(Mammalia) aligned 14 sequences
# cH4_(Mammalia) Alignment length: 16
# Processing  cH4_(Vertebrata)
# 	 Node is internal, progressive alignment:
# 		 For cH4_(Vertebrata) aligned 0 sequences
# 		 Adding child cH4_(Vertebrata) aligned 16 sequences
# cH4_(Vertebrata) Alignment length: 16
# Processing  cH4_(Animals)
# 	 Node is internal, progressive alignment:
# 		 For cH4_(Animals) aligned 5 sequences
# 		 Adding child cH4_(Animals) aligned 16 sequences
# cH4_(Animals) Alignment length: 21
# Processing  cH4_(Fungi)
# cH4_(Fungi) Alignment length: 1
# Processing  cH4_(Chlorophyta)
# cH4_(Chlorophyta) Alignment length: 0
# Processing  cH4_(Embryophyta)
# cH4_(Embryophyta) Alignment length: 2
# Processing  cH4_(Plants)
# 	 Node is internal, progressive alignment:
# 		 For cH4_(Plants) aligned 0 sequences
# 		 Adding child cH4_(Plants) aligned 0 sequences
# 		 Adding child cH4_(Plants) aligned 2 sequences
# cH4_(Plants) Alignment length: 2
# Processing  cH4_(Protists)
# cH4_(Protists) Alignment length: 3
# Processing  cH4
# 	 Node is internal, progressive alignment:
# 		 For cH4 aligned 0 sequences
# 		 Adding child cH4 aligned 21 sequences
# 		 Adding child cH4 aligned 1 sequences
# 		 Adding child cH4 aligned 2 sequences
# 		 Adding child cH4 aligned 3 sequences
# cH4 Alignment length: 27
# Processing  H4.G_(Hominidae)
# H4.G_(Hominidae) Alignment length: 1
# Processing  H4.V_(Trypanosomatidae)
# H4.V_(Trypanosomatidae) Alignment length: 1
# Processing  H4
# 	 Node is internal, progressive alignment:
# 		 For H4 aligned 0 sequences
# 		 Adding child H4 aligned 27 sequences
# 		 Adding child H4 aligned 1 sequences
# 		 Adding child H4 aligned 1 sequences
# H4 Alignment length: 29
# Processing  cH1.1_(Homo_sapiens)
# cH1.1_(Homo_sapiens) Alignment length: 1
# Processing  cH1.1
# 	 Node is internal, progressive alignment:
# 		 For cH1.1 aligned 0 sequences
# 		 Adding child cH1.1 aligned 1 sequences
# cH1.1 Alignment length: 1
# Processing  cH1.2_(Homo_sapiens)
# cH1.2_(Homo_sapiens) Alignment length: 1
# Processing  cH1.2
# 	 Node is internal, progressive alignment:
# 		 For cH1.2 aligned 0 sequences
# 		 Adding child cH1.2 aligned 1 sequences
# cH1.2 Alignment length: 1
# Processing  cH1.3_(Homo_sapiens)
# cH1.3_(Homo_sapiens) Alignment length: 1
# Processing  cH1.3
# 	 Node is internal, progressive alignment:
# 		 For cH1.3 aligned 0 sequences
# 		 Adding child cH1.3 aligned 1 sequences
# cH1.3 Alignment length: 1
# Processing  cH1.4_(Homo_sapiens)
# cH1.4_(Homo_sapiens) Alignment length: 1
# Processing  cH1.4
# 	 Node is internal, progressive alignment:
# 		 For cH1.4 aligned 0 sequences
# 		 Adding child cH1.4 aligned 1 sequences
# cH1.4 Alignment length: 1
# Processing  cH1.5_(Homo_sapiens)
# cH1.5_(Homo_sapiens) Alignment length: 1
# Processing  cH1.5
# 	 Node is internal, progressive alignment:
# 		 For cH1.5 aligned 0 sequences
# 		 Adding child cH1.5 aligned 1 sequences
# cH1.5 Alignment length: 1
# Processing  cH1.6_(Homo_sapiens)
# cH1.6_(Homo_sapiens) Alignment length: 1
# Processing  cH1.6
# 	 Node is internal, progressive alignment:
# 		 For cH1.6 aligned 7 sequences
# 		 Adding child cH1.6 aligned 1 sequences
# cH1.6 Alignment length: 8
# Processing  cH1
# 	 Node is internal, progressive alignment:
# 		 For cH1 aligned 0 sequences
# 		 Adding child cH1 aligned 1 sequences
# 		 Adding child cH1 aligned 1 sequences
# 		 Adding child cH1 aligned 1 sequences
# 		 Adding child cH1 aligned 1 sequences
# 		 Adding child cH1 aligned 1 sequences
# 		 Adding child cH1 aligned 8 sequences
# cH1 Alignment length: 13
# Processing  generic_H1
# generic_H1 Alignment length: 13
# Processing  H1.0_(Homo_sapiens)
# H1.0_(Homo_sapiens) Alignment length: 1
# Processing  H1.0
# 	 Node is internal, progressive alignment:
# 		 For H1.0 aligned 14 sequences
# 		 Adding child H1.0 aligned 1 sequences
# H1.0 Alignment length: 15
# Processing  H1.10_(Homo_sapiens)
# H1.10_(Homo_sapiens) Alignment length: 1
# Processing  H1.10
# 	 Node is internal, progressive alignment:
# 		 For H1.10 aligned 5 sequences
# 		 Adding child H1.10 aligned 1 sequences
# H1.10 Alignment length: 6
# Processing  H1.8_(Homo_sapiens)
# H1.8_(Homo_sapiens) Alignment length: 2
# Processing  OO_H1.8
# 	 Node is internal, progressive alignment:
# 		 For OO_H1.8 aligned 1 sequences
# 		 Adding child OO_H1.8 aligned 2 sequences
# OO_H1.8 Alignment length: 3
# Processing  scH1
# scH1 Alignment length: 2
# Processing  H1.7_(Homo_sapiens)
# H1.7_(Homo_sapiens) Alignment length: 1
# Processing  TS_H1.7
# 	 Node is internal, progressive alignment:
# 		 For TS_H1.7 aligned 1 sequences
# 		 Adding child TS_H1.7 aligned 1 sequences
# TS_H1.7 Alignment length: 2
# Processing  TS_H1.9
# TS_H1.9 Alignment length: 3
# Processing  H1
# 	 Node is internal, progressive alignment:
# 		 For H1 aligned 0 sequences
# 		 Adding child H1 aligned 13 sequences
# 		 Adding child H1 aligned 13 sequences
# 		 Adding child H1 aligned 15 sequences
# 		 Adding child H1 aligned 6 sequences
# 		 Adding child H1 aligned 3 sequences
# 		 Adding child H1 aligned 2 sequences
# 		 Adding child H1 aligned 2 sequences
# 		 Adding child H1 aligned 3 sequences
# H1 Alignment length: 57
# Processing  Capstones_(Methanobrevibacter)
# Capstones_(Methanobrevibacter) Alignment length: 12
# Processing  Capstone_(Methanosphaera)
# Capstone_(Methanosphaera) Alignment length: 9
# Processing  Capstone
# 	 Node is internal, progressive alignment:
# 		 For Capstone aligned 0 sequences
# 		 Adding child Capstone aligned 12 sequences
# 		 Adding child Capstone aligned 9 sequences
# Capstone Alignment length: 21
# Processing  Bridge_(Methanococcales)
# Bridge_(Methanococcales) Alignment length: 39
# Processing  Coiled-coil
# Coiled-coil Alignment length: 228
# Processing  Phage-histones
# Phage-histones Alignment length: 7
# Processing  RdgC-histones
# RdgC-histones Alignment length: 17
# Processing  DNA_bridging
# 	 Node is internal, progressive alignment:
# 		 For DNA_bridging aligned 0 sequences
# 		 Adding child DNA_bridging aligned 39 sequences
# 		 Adding child DNA_bridging aligned 228 sequences
# 		 Adding child DNA_bridging aligned 7 sequences
# 		 Adding child DNA_bridging aligned 17 sequences
# DNA_bridging Alignment length: 291
# Processing  Filament_forming
# Filament_forming Alignment length: 211
# Processing  FtF
# FtF Alignment length: 1481
# Processing  H1-like_(Viruses)
# H1-like_(Viruses) Alignment length: 12
# Processing  H2A-like_(Viruses)
# H2A-like_(Viruses) Alignment length: 11
# Processing  H2B-like_(Viruses)
# H2B-like_(Viruses) Alignment length: 15
# Processing  H3-like_(Viruses)
# H3-like_(Viruses) Alignment length: 45
# Processing  H4-like_(Viruses)
# H4-like_(Viruses) Alignment length: 45
# Processing  HMfA_(Methanothermus_fervidus)
# HMfA_(Methanothermus_fervidus) Alignment length: 2
# Processing  HMfA_(Methanobacteriales)
# 	 Node is internal, progressive alignment:
# 		 For HMfA_(Methanobacteriales) aligned 0 sequences
# 		 Adding child HMfA_(Methanobacteriales) aligned 2 sequences
# HMfA_(Methanobacteriales) Alignment length: 2
# Processing  HMfB_(Methanothermus_fervidus)
# HMfB_(Methanothermus_fervidus) Alignment length: 2
# Processing  HMfB_(Methanobacteriales)
# 	 Node is internal, progressive alignment:
# 		 For HMfB_(Methanobacteriales) aligned 0 sequences
# 		 Adding child HMfB_(Methanobacteriales) aligned 2 sequences
# HMfB_(Methanobacteriales) Alignment length: 2
# Processing  HTkA_(Thermococcus_kodakarensis)
# HTkA_(Thermococcus_kodakarensis) Alignment length: 4
# Processing  HTkA_(Thermococcales)
# 	 Node is internal, progressive alignment:
# 		 For HTkA_(Thermococcales) aligned 55 sequences
# 		 Adding child HTkA_(Thermococcales) aligned 4 sequences
# HTkA_(Thermococcales) Alignment length: 59
# Processing  HTkB_(Thermococcus_kodakarensis)
# HTkB_(Thermococcus_kodakarensis) Alignment length: 4
# Processing  HTkB_(Thermococcales)
# 	 Node is internal, progressive alignment:
# 		 For HTkB_(Thermococcales) aligned 56 sequences
# 		 Adding child HTkB_(Thermococcales) aligned 4 sequences
# HTkB_(Thermococcales) Alignment length: 60
# Processing  Nucleosomal
# 	 Node is internal, progressive alignment:
# 		 For Nucleosomal aligned 2451 sequences
# 		 Adding child Nucleosomal aligned 2 sequences
# 		 Adding child Nucleosomal aligned 2 sequences
# 		 Adding child Nucleosomal aligned 59 sequences
# 		 Adding child Nucleosomal aligned 60 sequences
# Nucleosomal Alignment length: 2574
# Processing  Singlet
# 	 Node is internal, progressive alignment:
# 		 For Singlet aligned 0 sequences
# 		 Adding child Singlet aligned 21 sequences
# 		 Adding child Singlet aligned 291 sequences
# 		 Adding child Singlet aligned 211 sequences
# 		 Adding child Singlet aligned 1481 sequences
# 		 Adding child Singlet aligned 12 sequences
# 		 Adding child Singlet aligned 11 sequences
# 		 Adding child Singlet aligned 15 sequences
# 		 Adding child Singlet aligned 45 sequences
# 		 Adding child Singlet aligned 45 sequences
# 		 Adding child Singlet aligned 2574 sequences
# Singlet Alignment length: 4706
# Processing  H2A-H2B-like_(Viruses)
# H2A-H2B-like_(Viruses) Alignment length: 2
# Processing  H2B-H2A-like_(Viruses)
# H2B-H2A-like_(Viruses) Alignment length: 47
# Processing  H4-H3-like_(Viruses)
# H4-H3-like_(Viruses) Alignment length: 39
# Processing  Doublet
# 	 Node is internal, progressive alignment:
# 		 For Doublet aligned 24 sequences
# 		 Adding child Doublet aligned 2 sequences
# 		 Adding child Doublet aligned 47 sequences
# 		 Adding child Doublet aligned 39 sequences
# Doublet Alignment length: 112
# Processing  H2B-H2A-H3-like_(Viruses)
# H2B-H2A-H3-like_(Viruses) Alignment length: 32
# Processing  Triplet
# 	 Node is internal, progressive alignment:
# 		 For Triplet aligned 0 sequences
# 		 Adding child Triplet aligned 32 sequences
# Triplet Alignment length: 32
# Processing  H2B-H2A-H3-H4-like_(Viruses)
# H2B-H2A-H3-H4-like_(Viruses) Alignment length: 6
# Processing  H2B-H2A-H4-H3-like_(Viruses)
# H2B-H2A-H4-H3-like_(Viruses) Alignment length: 5
# Processing  H4-H3-H2B-H2A-like_(Viruses)
# H4-H3-H2B-H2A-like_(Viruses) Alignment length: 2
# Processing  Quadruplet
# 	 Node is internal, progressive alignment:
# 		 For Quadruplet aligned 0 sequences
# 		 Adding child Quadruplet aligned 6 sequences
# 		 Adding child Quadruplet aligned 5 sequences
# 		 Adding child Quadruplet aligned 2 sequences
# Quadruplet Alignment length: 13
# Processing
# CPU times: user 9.47 s, sys: 4.6 s, total: 14.1 s
# Wall time: 37min 8s

# %% [markdown]
# # Generate GFFs

# %%
curated_seeds_msa_form_files = {}
for node in hist_tree.traverse("postorder"):
    if os.path.isfile(
        f"{DIR}/draft_seeds/{node.name.replace('(', '').replace(')', '')}.fasta"
    ):
        print("Loading ", node.name)
        curated_seeds_msa_form_files[node.name] = (
            AlignIO.read(
                f"{DIR}/draft_seeds/{node.name.replace('(', '').replace(')', '')}.fasta",
                "fasta",
            )
            if os.path.getsize(
                f"{DIR}/draft_seeds/{node.name.replace('(', '').replace(')', '')}.fasta"
            )
            > 0
            else []
        )
# Out:
# Loading  cH2A.10_(Homo_sapiens)
# Loading  cH2A.11_(Homo_sapiens)
# Loading  cH2A.1_(Homo_sapiens)
# Loading  cH2A.2_(Homo_sapiens)
# Loading  cH2A.3_(Homo_sapiens)
# Loading  cH2A.4_(Homo_sapiens)
# Loading  cH2A.5_(Homo_sapiens)
# Loading  cH2A.6_(Homo_sapiens)
# Loading  cH2A.7_(Homo_sapiens)
# Loading  cH2A.8_(Homo_sapiens)
# Loading  cH2A.9_(Homo_sapiens)
# Loading  cH2A_(Homo_sapiens)
# Loading  cH2A.1_(Mus_musculus)
# Loading  cH2A_(Mus_musculus)
# Loading  cH2A_(Mammalia)
# Loading  cH2A_(Vertebrata)
# Loading  cH2A_(Animals)
# Loading  cH2A_(Fungi)
# Loading  cH2A_(Chlorophyta)
# Loading  cH2A_(Embryophyta)
# Loading  cH2A_(Plants)
# Loading  cH2A_(Protists)
# Loading  cH2A
# Loading  gH2A_(Lilium)
# Loading  H2A.J_(Homo_sapiens)
# Loading  H2A.J
# Loading  H2A.M_(Viridiplantae)
# Loading  H2A.R
# Loading  H2A.W_(Magnoliopsida)
# Loading  H2A.X_(Homo_sapiens)
# Loading  H2A.X_(Mus_musculus)
# Loading  H2A.X_(Mammalia)
# Loading  H2A.X_(Vertebrata)
# Loading  H2A.X_(Animals)
# Loading  H2A.X_(Fungi)
# Loading  H2A.X_(Plants)
# Loading  H2A.X_(Protists)
# Loading  H2A.X
# Loading  H2A.Z.1_(Homo_sapiens)
# Loading  H2A.Z.1_(Primates)
# Loading  H2A.Z.1_(Chordata)
# Loading  H2A.Z.2.s1_(Homo_sapiens)
# Loading  H2A.Z.2.s1_(Primates)
# Loading  H2A.Z.2.s2_(Homo_sapiens)
# Loading  H2A.Z.2.s2_(Primates)
# Loading  H2A.Z.2_(Primates)
# Loading  H2A.Z.2_(Chordata)
# Loading  H2A.Z
# Loading  macroH2A.1.s1_(Homo_sapiens)
# Loading  macroH2A.1.s1_(Mammalia)
# Loading  macroH2A.1.s2_(Homo_sapiens)
# Loading  macroH2A.1.s2_(Mammalia)
# Loading  macroH2A.1_(Mammalia)
# Loading  macroH2A.2_(Homo_sapiens)
# Loading  macroH2A.2_(Mammalia)
# Loading  macroH2A
# Loading  H2A.B.1_(Homo_sapiens)
# Loading  H2A.B.2_(Homo_sapiens)
# Loading  H2A.B_(Homo_sapiens)
# Loading  H2A.B.1_(Mus_musculus)
# Loading  H2A.B.2_(Mus_musculus)
# Loading  H2A.B.3_(Mus_musculus)
# Loading  H2A.B_(Mus_musculus)
# Loading  H2A.B_(Eutheria)
# Loading  H2A.L.1_(Homo_sapiens)
# Loading  H2A.L.3_(Homo_sapiens)
# Loading  H2A.L_(Homo_sapiens)
# Loading  H2A.L.1_(Mus_musculus)
# Loading  H2A.L.2_(Mus_musculus)
# Loading  H2A.L.3_(Mus_musculus)
# Loading  H2A.L_(Mus_musculus)
# Loading  H2A.L_(Eutheria)
# Loading  H2A.P_(Homo_sapiens)
# Loading  H2A.P_(Mus_musculus)
# Loading  H2A.P_(Eutheria)
# Loading  H2A.Q_(Eutheria)
# Loading  short_H2A_(Eutheria)
# Loading  H2A
# Loading  cH2B.10_(Homo_sapiens)
# Loading  cH2B.11_(Homo_sapiens)
# Loading  cH2B.12_(Homo_sapiens)
# Loading  cH2B.13_(Homo_sapiens)
# Loading  cH2B.14_(Homo_sapiens)
# Loading  cH2B.15_(Homo_sapiens)
# Loading  cH2B.1_(Homo_sapiens)
# Loading  cH2B.2_(Homo_sapiens)
# Loading  cH2B.3_(Homo_sapiens)
# Loading  cH2B.4_(Homo_sapiens)
# Loading  cH2B.5_(Homo_sapiens)
# Loading  cH2B.6_(Homo_sapiens)
# Loading  cH2B.7_(Homo_sapiens)
# Loading  cH2B.8_(Homo_sapiens)
# Loading  cH2B.9_(Homo_sapiens)
# Loading  cH2B_(Homo_sapiens)
# Loading  cH2B.1_(Mus_musculus)
# Loading  cH2B.E_(Mus_musculus)
# Loading  cH2B_(Mus_musculus)
# Loading  cH2B_(Mammalia)
# Loading  cH2B_(Vertebrata)
# Loading  cH2B_(Animals)
# Loading  cH2B_(Fungi)
# Loading  cH2B_(Chlorophyta)
# Loading  cH2B_(Embryophyta)
# Loading  cH2B_(Plants)
# Loading  cH2B_(Protists)
# Loading  cH2B
# Loading  CS_H2B_(Echinoidea)
# Loading  early_H2B_(Echinoidea)
# Loading  gH2B_(Lilium)
# Loading  H2B.K_(Homo_sapiens)
# Loading  H2B.K
# Loading  H2B.L
# Loading  H2B.N_(Homo_sapiens)
# Loading  H2B.N
# Loading  H2B.O_(Ornithorhynchus_anatinus)
# Loading  H2B.S_(Magnoliopsida)
# Loading  H2B.V_(Trypanosoma)
# Loading  H2B.W.1_(Homo_sapiens)
# Loading  H2B.W.2_(Homo_sapiens)
# Loading  H2B.W_(Homo_sapiens)
# Loading  H2B.W
# Loading  H2B.Z_(Apicomplexa)
# Loading  late_H2B_(Echinoidea)
# Loading  sperm_H2B_(Echinoidea)
# Loading  H2B
# Loading  cH3.1_(Homo_sapiens)
# Loading  cH3.1_(Mammalia)
# Loading  cH3.2_(Homo_sapiens)
# Loading  cH3.2_(Mammalia)
# Loading  cH3_(Mammalia)
# Loading  cH3_(Vertebrata)
# Loading  cH3_(Animals)
# Loading  cH3_(Fungi)
# Loading  cH3_(Chlorophyta)
# Loading  cH3_(Embryophyta)
# Loading  cH3_(Plants)
# Loading  cH3_(Protists)
# Loading  cH3
# Loading  cenH3.1_(Culicidae)
# Loading  cenH3.2_(Culicidae)
# Loading  cenH3.3_(Aedes)
# Loading  cenH3_(Culicidae)
# Loading  cenH3.1_(Drosophilidae)
# Loading  cenH3.2_(Drosophila_eugracilis)
# Loading  cenH3.3_(Montium)
# Loading  cenH3.4_(Montium)
# Loading  cenH3.5_(Drosophila)
# Loading  cenH3.6_(Repleta)
# Loading  cenH3_(Drosophilidae)
# Loading  cenH3_(Insecta)
# Loading  cenH3_(Homo_sapiens)
# Loading  cenH3_(Mammalia)
# Loading  cenH3_(Animals)
# Loading  cenH3_(Fungi)
# Loading  cenH3.1_(Triticeae)
# Loading  cenH3.2_(Triticeae)
# Loading  cenH3_(Triticeae)
# Loading  cenH3.1_(Vigna_unguiculata)
# Loading  cenH3.2_(Vigna_unguiculata)
# Loading  cenH3_(Vigna_unguiculata)
# Loading  cenH3_(Plants)
# Loading  cenH3_(Protists)
# Loading  cenH3
# Loading  H3-like_(Plants)
# Loading  H3.10_(Arabidopsis)
# Loading  H3.14_(Arabidopsis)
# Loading  H3.3_(Homo_sapiens)
# Loading  H3.3_(Animals)
# Loading  H3.3_(Ascomycota)
# Loading  H3.3_(Fungi)
# Loading  H3.3_(Plants)
# Loading  H3.3_(Protists)
# Loading  H3.3
# Loading  H3.4_(Homo_sapiens)
# Loading  H3.4_(Mammalia)
# Loading  H3.5_(Homo_sapiens)
# Loading  H3.5_(Hominidae)
# Loading  H3.7_(Homo_sapiens)
# Loading  H3.B_(Giardia)
# Loading  H3.P_(Euplotes_crassus)
# Loading  H3.V_(Trypanosomatidae)
# Loading  H3.Y.1_(Homo_sapiens)
# Loading  H3.Y.1_(Primates)
# Loading  H3.Y.2_(Homo_sapiens)
# Loading  H3.Y.2_(Primates)
# Loading  H3.Y_(Primates)
# Loading  H3
# Loading  cH4_(Homo_sapiens)
# Loading  cH4_(Mammalia)
# Loading  cH4_(Vertebrata)
# Loading  cH4_(Animals)
# Loading  cH4_(Fungi)
# Loading  cH4_(Chlorophyta)
# Loading  cH4_(Embryophyta)
# Loading  cH4_(Plants)
# Loading  cH4_(Protists)
# Loading  cH4
# Loading  H4.G_(Hominidae)
# Loading  H4.V_(Trypanosomatidae)
# Loading  H4
# Loading  cH1.1_(Homo_sapiens)
# Loading  cH1.1
# Loading  cH1.2_(Homo_sapiens)
# Loading  cH1.2
# Loading  cH1.3_(Homo_sapiens)
# Loading  cH1.3
# Loading  cH1.4_(Homo_sapiens)
# Loading  cH1.4
# Loading  cH1.5_(Homo_sapiens)
# Loading  cH1.5
# Loading  cH1.6_(Homo_sapiens)
# Loading  cH1.6
# Loading  cH1
# Loading  generic_H1
# Loading  H1.0_(Homo_sapiens)
# Loading  H1.0
# Loading  H1.10_(Homo_sapiens)
# Loading  H1.10
# Loading  H1.8_(Homo_sapiens)
# Loading  OO_H1.8
# Loading  scH1
# Loading  H1.7_(Homo_sapiens)
# Loading  TS_H1.7
# Loading  TS_H1.9
# Loading  H1
# Loading  Capstones_(Methanobrevibacter)
# Loading  Capstone_(Methanosphaera)
# Loading  Capstone
# Loading  Bridge_(Methanococcales)
# Loading  Coiled-coil
# Loading  Phage-histones
# Loading  RdgC-histones
# Loading  DNA_bridging
# Loading  Filament_forming
# Loading  FtF
# Loading  H1-like_(Viruses)
# Loading  H2A-like_(Viruses)
# Loading  H2B-like_(Viruses)
# Loading  H3-like_(Viruses)
# Loading  H4-like_(Viruses)
# Loading  HMfA_(Methanothermus_fervidus)
# Loading  HMfA_(Methanobacteriales)
# Loading  HMfB_(Methanothermus_fervidus)
# Loading  HMfB_(Methanobacteriales)
# Loading  HTkA_(Thermococcus_kodakarensis)
# Loading  HTkA_(Thermococcales)
# Loading  HTkB_(Thermococcus_kodakarensis)
# Loading  HTkB_(Thermococcales)
# Loading  Nucleosomal
# Loading  Singlet
# Loading  H2A-H2B-like_(Viruses)
# Loading  H2B-H2A-like_(Viruses)
# Loading  H4-H3-like_(Viruses)
# Loading  Doublet
# Loading  H2B-H2A-H3-like_(Viruses)
# Loading  Triplet
# Loading  H2B-H2A-H3-H4-like_(Viruses)
# Loading  H2B-H2A-H4-H3-like_(Viruses)
# Loading  H4-H3-H2B-H2A-like_(Viruses)
# Loading  Quadruplet

# %%
generate_gff(curated_seeds_msa_form_files, f"{DIR}/draft_seeds")

# %% [markdown]
# # Generate trees

# %%
generate_core_seeds(curated_seeds_msa_form_files, f"{DIR}/draft_seeds_core")

# %%
def run_bash_command(command_string):
    try:
        # Запускаем команду bash из строки
        result = subprocess.run(
            ["bash", "-c", command_string],
            check=True,
            text=True,
            capture_output=True,
            # stdout=subprocess.DEVNULL,
            # stderr=subprocess.DEVNULL,
        )
    except subprocess.CalledProcessError as e:
        print("Ошибка выполнения скрипта:", e.stderr)
        # print("Ошибка выполнения скрипта:", e)

# %%
# shutil.rmtree("tmp/")

# %%
try:
    for node in hist_tree.traverse("postorder"):
        if os.path.isfile(
            f"{DIR}/draft_seeds/{node.name.replace('(', '').replace(')', '')}.fasta"
        ) and os.path.isfile(
            f"{DIR}/draft_seeds_core/{node.name.replace('(', '').replace(')', '')}.fasta"
        ):
            print("Building ", node.name)
            name = node.name.replace("(", "").replace(")", "")
            os.makedirs("tmp/")
            run_bash_command(
                f"FastTree -nosupport < {DIR}/draft_seeds_core/{name}.fasta > tmp/tree 2> /dev/null"
            )
            run_bash_command(
                f"sed '$ s/.$/Consensus;/' tmp/tree > {DIR}/draft_seeds/{name}.tree"
            )
            shutil.rmtree("tmp/")  # rm -rf tmp dir
except:
    shutil.rmtree("tmp/")  # rm -rf tmp dir
# Out:
# Building  cH2A.10_(Homo_sapiens)
# Building  cH2A.11_(Homo_sapiens)
# Building  cH2A.1_(Homo_sapiens)
# Building  cH2A.2_(Homo_sapiens)
# Building  cH2A.3_(Homo_sapiens)
# Building  cH2A.4_(Homo_sapiens)
# Building  cH2A.5_(Homo_sapiens)
# Building  cH2A.6_(Homo_sapiens)
# Building  cH2A.7_(Homo_sapiens)
# Building  cH2A.8_(Homo_sapiens)
# Building  cH2A.9_(Homo_sapiens)
# Building  cH2A_(Homo_sapiens)
# Building  cH2A.1_(Mus_musculus)
# Building  cH2A_(Mus_musculus)
# Building  cH2A_(Mammalia)
# Building  cH2A_(Vertebrata)
# Building  cH2A_(Animals)
# Building  cH2A_(Fungi)
# Building  cH2A_(Chlorophyta)
# Building  cH2A_(Embryophyta)
# Building  cH2A_(Plants)
# Building  cH2A_(Protists)
# Building  cH2A
# Building  gH2A_(Lilium)
# Building  H2A.J_(Homo_sapiens)
# Building  H2A.J
# Building  H2A.M_(Viridiplantae)
# Building  H2A.R
# Building  H2A.W_(Magnoliopsida)
# Building  H2A.X_(Homo_sapiens)
# Building  H2A.X_(Mus_musculus)
# Building  H2A.X_(Mammalia)
# Building  H2A.X_(Vertebrata)
# Building  H2A.X_(Animals)
# Building  H2A.X_(Fungi)
# Building  H2A.X_(Plants)
# Building  H2A.X_(Protists)
# Building  H2A.X
# Building  H2A.Z.1_(Homo_sapiens)
# Building  H2A.Z.1_(Primates)
# Building  H2A.Z.1_(Chordata)
# Building  H2A.Z.2.s1_(Homo_sapiens)
# Building  H2A.Z.2.s1_(Primates)
# Building  H2A.Z.2.s2_(Homo_sapiens)
# Building  H2A.Z.2.s2_(Primates)
# Building  H2A.Z.2_(Primates)
# Building  H2A.Z.2_(Chordata)
# Building  H2A.Z
# Building  macroH2A.1.s1_(Homo_sapiens)
# Building  macroH2A.1.s1_(Mammalia)
# Building  macroH2A.1.s2_(Homo_sapiens)
# Building  macroH2A.1.s2_(Mammalia)
# Building  macroH2A.1_(Mammalia)
# Building  macroH2A.2_(Homo_sapiens)
# Building  macroH2A.2_(Mammalia)
# Building  macroH2A
# Building  H2A.B.1_(Homo_sapiens)
# Building  H2A.B.2_(Homo_sapiens)
# Building  H2A.B_(Homo_sapiens)
# Building  H2A.B.1_(Mus_musculus)
# Building  H2A.B.2_(Mus_musculus)
# Building  H2A.B.3_(Mus_musculus)
# Building  H2A.B_(Mus_musculus)
# Building  H2A.B_(Eutheria)
# Building  H2A.L.1_(Homo_sapiens)
# Building  H2A.L.3_(Homo_sapiens)
# Building  H2A.L_(Homo_sapiens)
# Building  H2A.L.1_(Mus_musculus)
# Building  H2A.L.2_(Mus_musculus)
# Building  H2A.L.3_(Mus_musculus)
# Building  H2A.L_(Mus_musculus)
# Building  H2A.L_(Eutheria)
# Building  H2A.P_(Homo_sapiens)
# Building  H2A.P_(Mus_musculus)
# Building  H2A.P_(Eutheria)
# Building  H2A.Q_(Eutheria)
# Building  short_H2A_(Eutheria)
# Building  H2A
# Building  cH2B.10_(Homo_sapiens)
# Building  cH2B.11_(Homo_sapiens)
# Building  cH2B.12_(Homo_sapiens)
# Building  cH2B.13_(Homo_sapiens)
# Building  cH2B.14_(Homo_sapiens)
# Building  cH2B.15_(Homo_sapiens)
# Building  cH2B.1_(Homo_sapiens)
# Building  cH2B.2_(Homo_sapiens)
# Building  cH2B.3_(Homo_sapiens)
# Building  cH2B.4_(Homo_sapiens)
# Building  cH2B.5_(Homo_sapiens)
# Building  cH2B.6_(Homo_sapiens)
# Building  cH2B.7_(Homo_sapiens)
# Building  cH2B.8_(Homo_sapiens)
# Building  cH2B.9_(Homo_sapiens)
# Building  cH2B_(Homo_sapiens)
# Building  cH2B.1_(Mus_musculus)
# Building  cH2B.E_(Mus_musculus)
# Building  cH2B_(Mus_musculus)
# Building  cH2B_(Mammalia)
# Building  cH2B_(Vertebrata)
# Building  cH2B_(Animals)
# Building  cH2B_(Fungi)
# Building  cH2B_(Chlorophyta)
# Building  cH2B_(Embryophyta)
# Building  cH2B_(Plants)
# Building  cH2B_(Protists)
# Building  cH2B
# Building  CS_H2B_(Echinoidea)
# Building  early_H2B_(Echinoidea)
# Building  gH2B_(Lilium)
# Building  H2B.K_(Homo_sapiens)
# Building  H2B.K
# Building  H2B.L
# Building  H2B.N_(Homo_sapiens)
# Building  H2B.N
# Building  H2B.O_(Ornithorhynchus_anatinus)
# Building  H2B.S_(Magnoliopsida)
# Building  H2B.V_(Trypanosoma)
# Building  H2B.W.1_(Homo_sapiens)
# Building  H2B.W.2_(Homo_sapiens)
# Building  H2B.W_(Homo_sapiens)
# Building  H2B.W
# Building  H2B.Z_(Apicomplexa)
# Building  late_H2B_(Echinoidea)
# Building  sperm_H2B_(Echinoidea)
# Building  H2B
# Building  cH3.1_(Homo_sapiens)
# Building  cH3.1_(Mammalia)
# Building  cH3.2_(Homo_sapiens)
# Building  cH3.2_(Mammalia)
# Building  cH3_(Mammalia)
# Building  cH3_(Vertebrata)
# Building  cH3_(Animals)
# Building  cH3_(Fungi)
# Building  cH3_(Embryophyta)
# Building  cH3_(Plants)
# Building  cH3_(Protists)
# Building  cH3
# Building  cenH3.1_(Culicidae)
# Building  cenH3.2_(Culicidae)
# Building  cenH3.3_(Aedes)
# Building  cenH3_(Culicidae)
# Building  cenH3.1_(Drosophilidae)
# Building  cenH3.2_(Drosophila_eugracilis)
# Building  cenH3.3_(Montium)
# Building  cenH3.4_(Montium)
# Building  cenH3.5_(Drosophila)
# Building  cenH3.6_(Repleta)
# Building  cenH3_(Drosophilidae)
# Building  cenH3_(Insecta)
# Building  cenH3_(Homo_sapiens)
# Building  cenH3_(Mammalia)
# Building  cenH3_(Animals)
# Building  cenH3_(Fungi)
# Building  cenH3.1_(Triticeae)
# Building  cenH3.2_(Triticeae)
# Building  cenH3_(Triticeae)
# Building  cenH3.1_(Vigna_unguiculata)
# Building  cenH3.2_(Vigna_unguiculata)
# Building  cenH3_(Vigna_unguiculata)
# Building  cenH3_(Plants)
# Building  cenH3_(Protists)
# Building  cenH3
# Building  H3-like_(Plants)
# Building  H3.10_(Arabidopsis)
# Building  H3.14_(Arabidopsis)
# Building  H3.3_(Homo_sapiens)
# Building  H3.3_(Animals)
# Building  H3.3
# Building  H3.4_(Homo_sapiens)
# Building  H3.4_(Mammalia)
# Building  H3.5_(Homo_sapiens)
# Building  H3.5_(Hominidae)
# Building  H3.7_(Homo_sapiens)
# Building  H3.B_(Giardia)
# Building  H3.P_(Euplotes_crassus)
# Building  H3.V_(Trypanosomatidae)
# Building  H3.Y.1_(Homo_sapiens)
# Building  H3.Y.1_(Primates)
# Building  H3.Y.2_(Homo_sapiens)
# Building  H3.Y.2_(Primates)
# Building  H3.Y_(Primates)
# Building  H3
# Building  cH4_(Homo_sapiens)
# Building  cH4_(Mammalia)
# Building  cH4_(Vertebrata)
# Building  cH4_(Animals)
# Building  cH4_(Fungi)
# Building  cH4_(Embryophyta)
# Building  cH4_(Plants)
# Building  cH4_(Protists)
# Building  cH4
# Building  H4.G_(Hominidae)
# Building  H4.V_(Trypanosomatidae)
# Building  H4
# Building  cH1.1_(Homo_sapiens)
# Building  cH1.1
# Building  cH1.2_(Homo_sapiens)
# Building  cH1.2
# Building  cH1.3_(Homo_sapiens)
# Building  cH1.3
# Building  cH1.4_(Homo_sapiens)
# Building  cH1.4
# Building  cH1.5_(Homo_sapiens)
# Building  cH1.5
# Building  cH1.6_(Homo_sapiens)
# Building  cH1.6
# Building  cH1
# Building  generic_H1
# Building  H1.0_(Homo_sapiens)
# Building  H1.0
# Building  H1.10_(Homo_sapiens)
# Building  H1.10
# Building  H1.8_(Homo_sapiens)
# Building  OO_H1.8
# Building  scH1
# Building  H1.7_(Homo_sapiens)
# Building  TS_H1.7
# Building  TS_H1.9
# Building  H1
# Building  Capstones_(Methanobrevibacter)
# Building  Capstone_(Methanosphaera)
# Building  Capstone
# Building  Bridge_(Methanococcales)
# Building  Coiled-coil
# Building  Phage-histones
# Building  RdgC-histones
# Building  DNA_bridging
# Building  Filament_forming
# Building  FtF
# Building  H1-like_(Viruses)
# Building  H2A-like_(Viruses)
# Building  H2B-like_(Viruses)
# Building  H3-like_(Viruses)
# Building  H4-like_(Viruses)
# Building  HMfA_(Methanothermus_fervidus)
# Building  HMfA_(Methanobacteriales)
# Building  HMfB_(Methanothermus_fervidus)
# Building  HMfB_(Methanobacteriales)
# Building  HTkA_(Thermococcus_kodakarensis)
# Building  HTkA_(Thermococcales)
# Building  HTkB_(Thermococcus_kodakarensis)
# Building  HTkB_(Thermococcales)
# Building  Nucleosomal
# Building  Singlet
# Building  H2A-H2B-like_(Viruses)
# Building  H2B-H2A-like_(Viruses)
# Building  H4-H3-like_(Viruses)
# Building  Doublet
# Building  H2B-H2A-H3-like_(Viruses)
# Building  Triplet
# Building  H2B-H2A-H3-H4-like_(Viruses)
# Building  H2B-H2A-H4-H3-like_(Viruses)
# Building  H4-H3-H2B-H2A-like_(Viruses)
# Building  Quadruplet

# %%
print("ok")
# Out:
# ok

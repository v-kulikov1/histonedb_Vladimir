# %%
import io

import pandas as pd
from Bio import Entrez, SeqIO
from mysql.connector import connection
from sshtunnel import SSHTunnelForwarder

# Укажите ваш email (обязательно для использования Entrez)
Entrez.email = "your.email@example.com"

# %%
with open("db_curated_server_info.txt", "r") as file:
    lines = file.readlines()

config = {}

for line in lines:
    line = line.strip()
    if line and not line.startswith("#"):
        key, value = line.split("=", 1)
        config[key] = value.strip()

server_name = config.get("server_name")
srever_port = int(config.get("srever_port"))
ssh_password = config.get("ssh_password")
ssh_username = config.get("ssh_username")
db_adress = config.get("db_adress")
db_port = int(config.get("db_port"))

# %%
tunnel = SSHTunnelForwarder(
    (server_name, srever_port),
    ssh_password=ssh_password,
    ssh_username=ssh_username,
    remote_bind_address=(db_adress, db_port),
)
tunnel.start()
print(tunnel.local_bind_port)
# Out:
# 44147

# %%
conn = connection.MySQLConnection(
    user="db_user",
    password="db_password",
    host="localhost",
    port=tunnel.local_bind_port,
    database="db_name",
)
cursor = conn.cursor()

# %%
query = "SHOW TABLES;"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('alternative_name',),
#  ('histone',),
#  ('histone_description',),
#  ('histone_has_publication',),
#  ('publication',),
#  ('sequence',),
#  ('sequence_has_publication',)]

# %%
# add_histone = (
#     "INSERT INTO histone "
#     "(id, level, taxonomic_span, taxonomic_span_id, description, parent) "
#     "VALUES (%(id)s, %(level)s, %(taxonomic_span)s, %(taxonomic_span_id)s, %(description)s, %(parent)s)"
# )
# add_histone_description = (
#     "INSERT INTO histone_description "
#     "(summary, taxonomy, genes, evolution, expression, knock_out, function, sequence, localization, deposition, structure, interactions, disease, caveats) "
#     "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
# )
add_publication = (
    "INSERT INTO publication "
    "(id, title, doi, author, year) "
    "VALUES (%(id)s, %(title)s, %(doi)s, %(author)s, %(year)s)"
)
# add_sequence = (
#     "INSERT INTO sequence "
#     "(accession, variant, gi, ncbi_gene_id, hgnc_gene_name, taxonomy_id, organism, phylum, class, taxonomy_group, info, sequence, variant_under_consideration) "
#     "VALUES (%(accession)s, %(variant)s, %(gi)s, %(ncbi_gene_id)s, %(hgnc_gene_name)s, %(taxonomy_id)s, %(organism)s, %(phylum)s, %(class)s, %(taxonomy_group)s, %(info)s, %(sequence)s, %(variant_under_consideration)s)"
# )
# add_sequence_has_publication = (
#     "INSERT INTO sequence_has_publication "
#     "(sequence_accession, publication_id) "
#     "VALUES (%s, %s)"
# )
add_alternate_names = (
    "INSERT INTO alternative_name "
    "(name, taxonomy, gene, splice, histone) "
    "VALUES (%(name)s, %(taxonomy)s, %(gene)s, %(splice)s, %(histone)s)"
)
add_histone_has_publication = (
    "INSERT INTO histone_has_publication "
    "(histone_id, publication_id) "
    "VALUES (%s, %s)"
)

# %%
data_histone_description = {
    "summary": None,
    "taxonomy": None,
    "genes": None,
    "evolution": None, 
    "expression": None,
    "knock_out": None,
    "function": None,
    "sequence": None,
    "localization": None,
    "deposition": None,
    "structure": None,
    "interactions": None,
    "disease": None,
    "caveats": None,
}

# %%
def get_taxonomy_data(record):
    import re
    import sys

    taxonomy_data = {}
    taxonomy_data["organism"] = record.annotations["organism"]
    try:
        for a in record.features[0].qualifiers["db_xref"]:
            text = re.search("(\S+):(\S+)", a).group(1)
            taxid = re.search("(\S+):(\S+)", a).group(2)
            if text == "taxon":
                print(f"Fetched taxid from NCBI {taxid}")
                taxonomy_data["taxonomy_id"] = int(taxid)
            else:
                continue
    except:
        print("!!!!!!Unable to get TAXID for this record setting it to 1")
        taxonomy_data["taxonomy_id"] = 1  # unable to identify

    lineage = dict()
    for i in range(10):
        try:
            handle = Entrez.efetch(
                id=taxonomy_data["taxonomy_id"], db="taxonomy", retmode="xml"
            )
            tax_data = Entrez.read(handle)
            lineage = {
                d["Rank"]: d["ScientificName"]
                for d in tax_data[0]["LineageEx"]
                if d["Rank"] in ["class", "phylum"]
            }
            break
        except:
            print(
                "Unexpected error: {}, Retrying, attempt {}".format(
                    sys.exc_info()[0], i
                )
            )
            if i == 9:
                print(
                    f"FATAL ERROR could not get class and phylum from NCBI after 10 attempts for taxid:{taxonomy_data['taxonomy_id']}. Will add None for class and phylum!"
                )
            else:
                continue
    taxonomy_data["phylum"] = lineage.get("phylum", None)
    taxonomy_data["class"] = lineage.get("class", None)
    if taxonomy_data["phylum"] is not None:
        taxonomy_data["phylum"] = str(taxonomy_data["phylum"])
    if taxonomy_data["class"] is not None:
        taxonomy_data["class"] = str(taxonomy_data["class"])
    return taxonomy_data

# %%
query = "SELECT * FROM sequence " "WHERE variant LIKE 'cH3%'"
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df["variant"].value_counts()
# Out:
# variant
# cH3                     23
# cH3.1_(Homo_sapiens)    10
# cH3.2_(Homo_sapiens)     3
# Name: count, dtype: int64

# %%
query = "SELECT * FROM sequence " "WHERE variant='cH4'"
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[["accession", "variant", "organism", "phylum", "class"]].to_dict(orient="records")
# Out:
# [{'accession': 'NP_001027352.1',
#   'variant': 'cH4',
#   'organism': 'Drosophila melanogaster',
#   'phylum': 'Arthropoda',
#   'class': 'Insecta'},
#  {'accession': 'NP_001032934.1',
#   'variant': 'cH4',
#   'organism': 'Gallus gallus',
#   'phylum': 'Chordata',
#   'class': 'Aves'},
#  {'accession': 'NP_001087926.1',
#   'variant': 'cH4',
#   'organism': 'Xenopus laevis',
#   'phylum': 'Chordata',
#   'class': 'Amphibia'},
#  {'accession': 'NP_001131585.1',
#   'variant': 'cH4',
#   'organism': 'Zea mays',
#   'phylum': 'Streptophyta',
#   'class': 'Magnoliopsida'},
#  {'accession': 'NP_009563.1',
#   'variant': 'cH4',
#   'organism': 'Saccharomyces cerevisiae S288C',
#   'phylum': 'Ascomycota',
#   'class': 'Saccharomycetes'},
#  {'accession': 'NP_180441.1',
#   'variant': 'cH4',
#   'organism': 'Arabidopsis thaliana',
#   'phylum': 'Streptophyta',
#   'class': 'Magnoliopsida'},
#  {'accession': 'NP_291074.1',
#   'variant': 'cH4',
#   'organism': 'Mus musculus',
#   'phylum': 'Chordata',
#   'class': 'Mammalia'},
#  {'accession': 'NP_492641.1',
#   'variant': 'cH4',
#   'organism': 'Caenorhabditis elegans',
#   'phylum': 'Nematoda',
#   'class': 'Chromadorea'},
#  {'accession': 'NP_999707.1',
#   'variant': 'cH4',
#   'organism': 'Strongylocentrotus purpuratus',
#   'phylum': 'Echinodermata',
#   'class': 'Echinoidea'},
#  {'accession': 'XP_001016593.1',
#   'variant': 'cH4',
#   'organism': 'Tetrahymena thermophila SB210',
#   'phylum': 'Ciliophora',
#   'class': 'Oligohymenophorea'},
#  {'accession': 'XP_012928609.1',
#   'variant': 'cH4',
#   'organism': 'Heterocephalus glaber',
#   'phylum': 'Chordata',
#   'class': 'Mammalia'},
#  {'accession': 'XP_951561.1',
#   'variant': 'cH4',
#   'organism': 'Trypanosoma brucei brucei TREU927',
#   'phylum': 'Euglenozoa',
#   'class': 'Kinetoplastea'}]

# %%
query = "SELECT * FROM alternative_name " "WHERE name='cid'"
cursor.execute(query)
pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
# Out:
#    id name taxonomy  gene splice         histone
# 0  65  cid     None  None   None  cenH3_(Plants)

# %%
query = "SELECT * FROM publication "
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].str.startswith("hara")]
# Out:
# Empty DataFrame
# Columns: [id, title, doi, author, year, pubmed_id]
# Index: []

# %%
query = (
    "SELECT * FROM histone as h LEFT JOIN histone_description as hd "
    "ON h.description = hd.id "
    # "WHERE h.id = 'H3.6_(Homo_sapiens)' "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df.iloc[:,0].str.contains("H3.6")]
# Out:
#                    id    level taxonomic_span taxonomic_span_id  description  \
# 17  cenH3.6_(Repleta)  variant  repleta group             32321        245.0
#
#                    parent     id  \
# 17  cenH3_(Drosophilidae)  245.0
#
#                                               summary taxonomy genes  ...  \
# 17  cenH3.6_(Repleta)  is a recently evolved centr...     None  None  ...
#
#    knock_out function sequence localization deposition structure interactions  \
# 17      None     None     None         None       None      None         None
#
#    disease caveats relations
# 17    None    None      None
#
# [1 rows x 22 columns]

# %%
df["genes"].values[0]
# Out:
# 'CENP-A nucleosomes are essential for chromosome segregation. A functional kinetochore interacts with active centromeric chromatin reached with CENP-A to form the mitotic spindle. Notably, in certain holocentric organisms, CENP-A appears dispensable for meiotic chromosome segregation while remaining essential for mitosis. As demonstrated in Caenorhabditis elegans, CENP-A loading is specifically eliminated following meiosis I, and RNAi-mediated depletion of CENP-A during meiosis fails to disrupt proper chromosome segregation [monen_differential_2005]. This stands in striking contrast to mitotic divisions, where CENP-A is absolutely required for kinetochore assembly and faithful chromosome segregation. Moreover, C. elegans and C. remanei possess a second cenH3 histone gene that likely performs specialized functions distinct from canonical CENP-A roles [monen_separase_2015]. For more detailed information see the "gene" section.'

# %%
query = "SELECT * FROM histone_description "
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
# df
for s in df.apply(lambda row: ''.join(row.astype(str)), axis=1):
    if "henikoff_heterochromatic_2000" in s:
        print(s)
        print("---------------")

# %%
query = "SHOW TABLES; "
cursor.execute(query)
pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
# Out:
#           Tables_in_db_name
# 0          alternative_name
# 1                   histone
# 2       histone_description
# 3   histone_has_publication
# 4               publication
# 5                  sequence
# 6  sequence_has_publication

# %%
query = (
    "SELECT s.accession, s.variant, s.organism, p.* FROM sequence s LEFT JOIN "
    "sequence_has_publication sp ON s.accession = sp.sequence_accession LEFT JOIN "
    "publication p ON sp.publication_id = p.id "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["variant"].str.startswith("H2A.Q", na=False)]
# Out:
#             accession           variant                              organism  \
# 1407       ELK02218.1  H2A.Q_(Eutheria)                       Pteropus alecto
# 2367   HISTDB_H2A_Q_0  H2A.Q_(Eutheria)                Cercopithecus aethiops
# 2368   HISTDB_H2A_Q_1  H2A.Q_(Eutheria)                  Pantholops hodgsonii
# 2369  HISTDB_H2A_Q_10  H2A.Q_(Eutheria)                       Ursus maritimus
# 2370  HISTDB_H2A_Q_11  H2A.Q_(Eutheria)                       Cercocebus atys
# 2371  HISTDB_H2A_Q_12  H2A.Q_(Eutheria)           Odobenus rosmarus divergens
# 2372  HISTDB_H2A_Q_13  H2A.Q_(Eutheria)                   Ceratotherium simum
# 2373  HISTDB_H2A_Q_14  H2A.Q_(Eutheria)                             Bos mutus
# 2374  HISTDB_H2A_Q_15  H2A.Q_(Eutheria)                       Pan troglodytes
# 2375  HISTDB_H2A_Q_16  H2A.Q_(Eutheria)                            Bos taurus
# 2376  HISTDB_H2A_Q_17  H2A.Q_(Eutheria)                        Equus caballus
# 2377  HISTDB_H2A_Q_18  H2A.Q_(Eutheria)                          Papio anubis
# 2378  HISTDB_H2A_Q_19  H2A.Q_(Eutheria)                 Pongo pygmaeus abelii
# 2379   HISTDB_H2A_Q_2  H2A.Q_(Eutheria)                     Ammotragus lervia
# 2380  HISTDB_H2A_Q_20  H2A.Q_(Eutheria)                            Sus scrofa
# 2381  HISTDB_H2A_Q_21  H2A.Q_(Eutheria)                      Nasalis larvatus
# 2382  HISTDB_H2A_Q_22  H2A.Q_(Eutheria)                   Nomascus leucogenys
# 2383   HISTDB_H2A_Q_3  H2A.Q_(Eutheria)                     Bison bison bison
# 2384   HISTDB_H2A_Q_4  H2A.Q_(Eutheria)                          Pan paniscus
# 2385   HISTDB_H2A_Q_5  H2A.Q_(Eutheria)                Mandrillus leucophaeus
# 2386   HISTDB_H2A_Q_6  H2A.Q_(Eutheria)                 Mustela putorius furo
# 2387   HISTDB_H2A_Q_7  H2A.Q_(Eutheria)  Giraffa camelopardalis tippelskirchi
# 2388   HISTDB_H2A_Q_8  H2A.Q_(Eutheria)                    Ovis aries musimon
# 2389   HISTDB_H2A_Q_9  H2A.Q_(Eutheria)                      Okapia johnstoni
# 6441   XP_010950849.1  H2A.Q_(Eutheria)                    Camelus bactrianus
# 6442   XP_010995375.1  H2A.Q_(Eutheria)                   Camelus dromedarius
# 6462   XP_013966888.1  H2A.Q_(Eutheria)                Canis lupus familiaris
# 6465   XP_015107649.1  H2A.Q_(Eutheria)                         Vicugna pacos
#
#             id title   doi author  year pubmed_id
# 1407  29549088  None  None   None  None      None
# 2367  29549088  None  None   None  None      None
# 2368  29549088  None  None   None  None      None
# 2369  29549088  None  None   None  None      None
# 2370  29549088  None  None   None  None      None
# 2371  29549088  None  None   None  None      None
# 2372  29549088  None  None   None  None      None
# 2373  29549088  None  None   None  None      None
# 2374  29549088  None  None   None  None      None
# 2375  29549088  None  None   None  None      None
# 2376  29549088  None  None   None  None      None
# 2377  29549088  None  None   None  None      None
# 2378  29549088  None  None   None  None      None
# 2379  29549088  None  None   None  None      None
# 2380  29549088  None  None   None  None      None
# 2381  29549088  None  None   None  None      None
# 2382  29549088  None  None   None  None      None
# 2383  29549088  None  None   None  None      None
# 2384  29549088  None  None   None  None      None
# 2385  29549088  None  None   None  None      None
# 2386  29549088  None  None   None  None      None
# 2387  29549088  None  None   None  None      None
# 2388  29549088  None  None   None  None      None
# 2389  29549088  None  None   None  None      None
# 6441  29549088  None  None   None  None      None
# 6442  29549088  None  None   None  None      None
# 6462  29549088  None  None   None  None      None
# 6465  29549088  None  None   None  None      None

# %% [markdown]
# # To Do H1
#
# ## <span style="color:black">Update description of cH1.1_(Homo_sapiens)</span>
#
# ### <span style="color:black">Update summary</span>
#
# ```cH1.1_(Homo sapiens) is a replication-dependent linker histone in humans that is essential during the early stages of embryogenesis [funaya_involvement_2023]. Human cH1.1 interacts with the phosphorylated form of the recombinant protein PC4 to mediate chromatin condensation [mustafi_phosphorylation-dependent_2022].```

# %% [markdown]
# # To Do H3
#
# ## <span style="color:black">Correct sequence class of HISTDB_H3_V_Trypanosomatidae_1 (delete first space)</span>
#
# ## <span style="color:black">Change sequence variant of cH3s</span>
#
# ```python
# [{'accession': 'CAA32434.1',
#   'variant': 'cH3_(Animals)'},
#  {'accession': 'NP_001027285.1',
#   'variant': 'cH3_(Animals)'},
#  {'accession': 'NP_001044904.1',
#   'variant': 'cH3_(Embryophyta)'},
#  {'accession': 'NP_001050276.1',
#   'variant': 'cH3_(Embryophyta)'},
#  {'accession': 'NP_001091119.1',
#   'variant': 'cH3_(Vertebrata)'},
#  {'accession': 'NP_001180643.1',
#   'variant': 'cH3.1_(Mammalia)'},
#  {'accession': 'NP_001268409.1',
#   'variant': 'cH3_(Animals)'},
#  {'accession': 'NP_189372.1',
#   'variant': 'cH3_(Embryophyta)'},
#  {'accession': 'NP_509344.1',
#   'variant': 'cH3_(Animals)'},
#  {'accession': 'NP_659539.1',
#   'variant': 'cH3.1_(Mammalia)'},
#  {'accession': 'XP_001016594.3',
#   'variant': 'cH3_(Protists)'},
#  {'accession': 'XP_001218942.1',
#   'variant': 'cH3_(Protists)'},
#  {'accession': 'XP_002288694.1',
#   'variant': 'cH3_(Protists)'},
#  {'accession': 'XP_002788889.1',
#   'variant': 'cH3_(Protists)'},
#  {'accession': 'XP_002977792.1',
#   'variant': 'cH3_(Embryophyta)'},
#  {'accession': 'XP_002999294.1',
#   'variant': 'cH3_(Protists)'},
#  {'accession': 'XP_460476.1',
#   'variant': 'cH3_(Fungi)'},
#  {'accession': 'XP_527254.2',
#   'variant': 'cH3.1_(Mammalia)'},
#  {'accession': 'XP_719887.1',
#   'variant': 'cH3_(Fungi)'},
#  {'accession': 'XP_724814.1',
#   'variant': 'cH3_(Protists)'}]
# ```

# %% [markdown]
# # To Do H4
#
# ## <span style="color:black">Change sequence variant of cH4s</span>
#
# ```python
# [{'accession': 'NP_001027352.1',
#   'variant': 'cH4_(Animals)'},
#  {'accession': 'NP_001032934.1',
#   'variant': 'cH4_(Animals)'},
#  {'accession': 'NP_001087926.1',
#   'variant': 'cH4_(Animals)'},
#  {'accession': 'NP_001131585.1',
#   'variant': 'cH4_(Embryophyta)'},
#  {'accession': 'NP_009563.1',
#   'variant': 'cH4_(Fungi)'},
#  {'accession': 'NP_180441.1',
#   'variant': 'cH4_(Embryophyta)'},
#  {'accession': 'NP_291074.1',
#   'variant': 'cH4_(Mammalia)'},
#  {'accession': 'NP_492641.1',
#   'variant': 'cH4_(Animals)'},
#  {'accession': 'NP_999707.1',
#   'variant': 'cH4_(Animals)'},
#  {'accession': 'XP_001016593.1',
#   'variant': 'cH4_(Protists)'},
#  {'accession': 'XP_012928609.1',
#   'variant': 'cH4_(Mammalia)'},
#  {'accession': 'XP_951561.1',
#   'variant': 'cH4_(Protists)'}]
# ```

# %% [markdown]
# # Close connections

# %%
cursor.close()
conn.close()
tunnel.stop()
